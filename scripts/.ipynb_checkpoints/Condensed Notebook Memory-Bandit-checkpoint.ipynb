# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
import numpy as np
import mne
import mne_connectivity
import pactools
from mne_connectivity import phase_slope_index, seed_target_indices, spectral_connectivity_epochs
from glob import glob
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from scipy.stats import zscore, linregress, ttest_ind, ttest_rel, ttest_1samp
import pandas as pd
from mne.preprocessing.bads import _find_outliers
import fooof
# Import plotting functions
from fooof.plts.spectra import plot_spectrum, plot_spectra
# Import the FOOOF object
from fooof import FOOOF
from fooof import FOOOFGroup
import os 
import joblib
import statsmodels.formula.api as smf
import statsmodels.api as sm
import pickle
from tqdm import tqdm
from IPython.display import clear_output
import warnings 

# I only want to see warnings once
warnings.filterwarnings('ignore')

from joblib import delayed, Parallel
from statsmodels.stats import multitest

# %% [markdown]
# Note: If you have installed this package in editable form on Minerva, you must append the local path! This is because Minerva requires that you point your package installs away from the local directory for space reasons, but editable packages have to be installed locally.

# %%
import sys
sys.path.append('/hpc/users/qasims01/resources/LFPAnalysis')

# %%
from LFPAnalysis import lfp_preprocess_utils, sync_utils, analysis_utils, nlx_utils, oscillation_utils, statistics_utils

# %%
import h5io

# %% [markdown]
# ## First, get the behavior data

# %% [markdown]
# This is from another notebook with a kernel and environment specifically for beahvior

# %% [markdown]
# note to seld: YOU MUST RUN EMU_BEHAV.ipynb BEFORE TO MAKE SURE YOU'VE PROCESSED ALL BEHAVIORS

# %%
base_dir = '/sc/arion' # this is the root directory for most un-archived data and results
load_dir = f'{base_dir}/work/qasims01/MemoryBanditData/EMU'

# Load the demographics data to get information about who has run the task
demo_file = f'{base_dir}/projects/guLab/Salman/EMU/MemoryBanditsDatabase.xlsx'
demo_data = pd.read_excel(demo_file, engine='openpyxl')
subj_df = demo_data[(demo_data.LongVersion==1) & (demo_data.Minerva==1)]

# Let's get rid of Iowa patients for now 

# subj_df = subj_df[subj_df.Site!='UI']
subj_df = subj_df[subj_df.MSSMCode!='UI002']

days = ['Day1', 'Day2']
subj_ids = subj_df.MSSMCode.values
subj_formats = subj_df.format.values
subj_sites = subj_df.Site.values
subj_days = subj_df.Day2.values

# %%
# load behavioral data
learn_df = pd.read_csv(f'{load_dir}/learn_df.csv')
combined_df = pd.read_csv(f'{load_dir}/combined_df.csv')

# Filter just to the participants in this notebook
learn_df = learn_df[learn_df.participant.isin(subj_ids)]
combined_df = combined_df[combined_df.participant.isin(subj_ids)]


# I enter the day information in stupidly 
combined_df.condition = combined_df.condition.apply(lambda x: 'Day1' if x=='day_1' else 'Day2' if x=='day_2' else np.nan)
# 'None's are kind of screwing things up a bit for me because I can't get a time from them (MS038). 
combined_df['recog_time'] = combined_df['recog_time'].apply(lambda x: float(x) if (~pd.isna(x)) & (x!='None') else np.nan)
# 
combined_df['baseline_start_mem'] = combined_df['baseline_start_mem'].apply(lambda x: float(x) if (~pd.isna(x)) & (x!='None') else np.nan)

# add RPE to the combined df dataframe: 

combined_df['rpe'] = np.nan
for ix, row in learn_df.iterrows():
    combined_df.loc[(combined_df.img_path==row.img_path) & (combined_df.participant==row.participant), 'rpe'] = row.rpe

# %% [markdown]
# ## Load, pre-process and re-reference the neural data

# %% [markdown]
# Run the initial loading and pre-processing

# %%
for ix, subj_id in enumerate(subj_ids): 
    site = subj_sites[ix]
    format = subj_formats[ix]
    for day in days:
        # Check if this day is in the dataset:
        if subj_df[subj_df.MSSMCode==subj_id][day].values[0] == 0:
            print (f'subject {subj_id} does not have Day 2 data')
            continue
        else:
            print(f'Working on subj {subj_id}')
            # Set paths
            load_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/neural/{day}'
            elec_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/anat/'
            save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'
            # Check if path exists for saving, and if not, make it
            if not os.path.exists(save_path):
                os.makedirs(save_path)

            # electrode files could either be csv or excel
            elec_files = glob(f'{elec_path}/*.csv') + glob(f'{elec_path}/*.xlsx')
            # There should really only be one, so grab it with the zero-index 
            elec_file = elec_files[0]

            # Make MNE file
            mne_data = lfp_preprocess_utils.make_mne(load_path=load_path, 
                                                     elec_path=elec_file,
                                                     format=format,
                                                     return_data=True,
                                                     site=site)
            
            # Save this data so that you don't need this step again:
            mne_data.save(f'{save_path}/raw_ieeg.fif', overwrite=True)
# Out:
# Working on subj MS038
# Unidentified data type in blank21
# Unidentified data type in blank14
# Unidentified data type in mic
# Unidentified data type in photo
# Unidentified data type in photodiode
# Unidentified data type in audio
# Unidentified data type in blank12
# Unidentified data type in blank11
# Unidentified data type in abs2
# Unidentified data type in blank22
# Unidentified data type in blank23
# Unidentified data type in blank13
# Unidentified data type in blank15
# Unidentified data type in chest1
# Unidentified data type in chest2
# Unidentified data type in ekg1
# Unidentified data type in abs1
# Creating RawArray with float64 data, n_channels=186, n_times=2157568
#     Range : 0 ... 2157567 =      0.000 ...  1078.784 secs
# Ready.
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 13201 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 168 out of 168 | elapsed:   15.1s finished
# Saving photodiode data to /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/photodiode.fif
# Writing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/photodiode.fif
# Closing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/photodiode.fif
# [done]
# Saving EEG data to /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/scalp_eeg_data.fif
# Writing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/scalp_eeg_data.fif
# Closing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/scalp_eeg_data.fif
# [done]
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file
#        name  lev_score
# 147  ralmm3   0.833333
# 148  rammf3   0.833333
# We have too many possible matches for raimm3! Select one manually from these candidates:ralmm3
#        name  lev_score
# 147  lhpit6   0.833333
# 148  rhplt6   0.833333
# We have too many possible matches for lhplt6! Select one manually from these candidates:lhpit6
#         name  lev_score
# 147  rhplt10   0.857143
# 148  lhpit10   0.857143
# We have too many possible matches for lhplt10! Select one manually from these candidates:lhpit10
#        name  lev_score
# 147  rammf6   0.833333
# 148  ralmm6   0.833333
# We have too many possible matches for raimm6! Select one manually from these candidates:ralmm6
#        name  lev_score
# 147  rhplt3   0.833333
# 148  lhpit3   0.833333
# We have too many possible matches for lhplt3! Select one manually from these candidates:lhpit3
#        name  lev_score
# 147  rhplt2   0.833333
# 148  lhpit2   0.833333
# We have too many possible matches for lhplt2! Select one manually from these candidates:lhpit2
#        name  lev_score
# 147  ralmm2   0.833333
# 148  rammf2   0.833333
# We have too many possible matches for raimm2! Select one manually from these candidates:ralmm2
#        name  lev_score
# 147  rammf5   0.833333
# 148  ralmm5   0.833333
# We have too many possible matches for raimm5! Select one manually from these candidates:ralmm5
#        name  lev_score
# 147  ralmm4   0.833333
# 148  rammf4   0.833333
# We have too many possible matches for raimm4! Select one manually from these candidates:ralmm4
#        name  lev_score
# 147  ralmm7   0.833333
# 148  rammf7   0.833333
# We have too many possible matches for raimm7! Select one manually from these candidates:ralmm7
#        name  lev_score
# 147  rhplt8   0.833333
# 148  lhpit8   0.833333
# We have too many possible matches for lhplt8! Select one manually from these candidates:lhpit8
#        name  lev_score
# 147  lhpit7   0.833333
# 148  rhplt7   0.833333
# We have too many possible matches for lhplt7! Select one manually from these candidates:lhpit7
#        name  lev_score
# 147  rhplt9   0.833333
# 148  lhpit9   0.833333
# We have too many possible matches for lhplt9! Select one manually from these candidates:lhpit9
#        name  lev_score
# 147  rhplt4   0.833333
# 148  lhpit4   0.833333
# We have too many possible matches for lhplt4! Select one manually from these candidates:lhpit4
#        name  lev_score
# 147  ralmm8   0.833333
# 148  rammf8   0.833333
# We have too many possible matches for raimm8! Select one manually from these candidates:ralmm8
#        name  lev_score
# 147  rhplt5   0.833333
# 148  lhpit5   0.833333
# We have too many possible matches for lhplt5! Select one manually from these candidates:lhpit5
#         name  lev_score
# 147  ralmm10   0.857143
# 148  rammf10   0.857143
# We have too many possible matches for raimm10! Select one manually from these candidates:ralmm10
#        name  lev_score
# 147  ralmm9   0.833333
# 148  rammf9   0.833333
# We have too many possible matches for raimm9! Select one manually from these candidates:ralmm9
#        name  lev_score
# 147  rammf1   0.833333
# 148  ralmm1   0.833333
# We have too many possible matches for raimm1! Select one manually from these candidates:ralmm1
#        name  lev_score
# 147  rhplt1   0.833333
# 148  lhpit1   0.833333
# We have too many possible matches for lhplt1! Select one manually from these candidates:lhpit1
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=-1)]: Done 149 out of 149 | elapsed:   18.8s finished
# Saving LFP data to /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/lfp_data.fif
# Writing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/lfp_data.fif
# Closing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/lfp_data.fif
# [done]
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/raw_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/raw_ieeg.fif
# [done]
# Working on subj MS038
# Data in numbered files
# Unidentified data type in blank12
# Unidentified data type in photodiode
# Unidentified data type in blank11
# Unidentified data type in blank13
# Unidentified data type in audio
# Unidentified data type in chest2
# Unidentified data type in chest1
# Unidentified data type in blank14
# Unidentified data type in blank22
# Unidentified data type in ekg2
# Unidentified data type in blank15
# Unidentified data type in blank23
# Unidentified data type in mic
# Unidentified data type in blank21
# Unidentified data type in abs1
# Unidentified data type in photo
# Unidentified data type in abs2
# Creating RawArray with float64 data, n_channels=186, n_times=902144
#     Range : 0 ... 902143 =      0.000 ...   451.072 secs
# Ready.
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 13201 samples (6.601 sec)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done 168 out of 168 | elapsed:    6.1s finished
# Saving photodiode data to /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/photodiode.fif
# Writing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/photodiode.fif
# Closing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/photodiode.fif
# [done]
# Saving EEG data to /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/scalp_eeg_data.fif
# Writing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/scalp_eeg_data.fif
# Closing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/scalp_eeg_data.fif
# [done]
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file
#        name  lev_score
# 147  rammf3   0.833333
# 148  ralmm3   0.833333
# We have too many possible matches for raimm3! Select one manually from these candidates:ralmm3
#        name  lev_score
# 147  lhpit6   0.833333
# 148  rhplt6   0.833333
# We have too many possible matches for lhplt6! Select one manually from these candidates:lhpit6
#         name  lev_score
# 147  lhpit10   0.857143
# 148  rhplt10   0.857143
# We have too many possible matches for lhplt10! Select one manually from these candidates:lhpit10
#        name  lev_score
# 147  rammf6   0.833333
# 148  ralmm6   0.833333
# We have too many possible matches for raimm6! Select one manually from these candidates:ralmm6
#        name  lev_score
# 147  lhpit3   0.833333
# 148  rhplt3   0.833333
# We have too many possible matches for lhplt3! Select one manually from these candidates:lhpit3
#        name  lev_score
# 147  rhplt2   0.833333
# 148  lhpit2   0.833333
# We have too many possible matches for lhplt2! Select one manually from these candidates:lhpit2
#        name  lev_score
# 147  rammf2   0.833333
# 148  ralmm2   0.833333
# We have too many possible matches for raimm2! Select one manually from these candidates:ralmm2
#        name  lev_score
# 147  rammf5   0.833333
# 148  ralmm5   0.833333
# We have too many possible matches for raimm5! Select one manually from these candidates:ralmm5
#        name  lev_score
# 147  ralmm4   0.833333
# 148  rammf4   0.833333
# We have too many possible matches for raimm4! Select one manually from these candidates:ralmm4
#        name  lev_score
# 147  rammf7   0.833333
# 148  ralmm7   0.833333
# We have too many possible matches for raimm7! Select one manually from these candidates:ralmm7
#        name  lev_score
# 147  rhplt8   0.833333
# 148  lhpit8   0.833333
# We have too many possible matches for lhplt8! Select one manually from these candidates:lhpit8
#        name  lev_score
# 147  rhplt7   0.833333
# 148  lhpit7   0.833333
# We have too many possible matches for lhplt7! Select one manually from these candidates:lhpit7
#        name  lev_score
# 147  lhpit9   0.833333
# 148  rhplt9   0.833333
# We have too many possible matches for lhplt9! Select one manually from these candidates:lhpit9
#        name  lev_score
# 147  rhplt4   0.833333
# 148  lhpit4   0.833333
# We have too many possible matches for lhplt4! Select one manually from these candidates:lhpit4
#        name  lev_score
# 147  ralmm8   0.833333
# 148  rammf8   0.833333
# We have too many possible matches for raimm8! Select one manually from these candidates:ralmm8
#        name  lev_score
# 147  rhplt5   0.833333
# 148  lhpit5   0.833333
# We have too many possible matches for lhplt5! Select one manually from these candidates:lhpit5
#         name  lev_score
# 147  rammf10   0.857143
# 148  ralmm10   0.857143
# We have too many possible matches for raimm10! Select one manually from these candidates:ralmm10
#        name  lev_score
# 147  ralmm9   0.833333
# 148  rammf9   0.833333
# We have too many possible matches for raimm9! Select one manually from these candidates:ralmm9
#        name  lev_score
# 147  ralmm1   0.833333
# 148  rammf1   0.833333
# We have too many possible matches for raimm1! Select one manually from these candidates:ralmm1
#        name  lev_score
# 147  rhplt1   0.833333
# 148  lhpit1   0.833333
# We have too many possible matches for lhplt1! Select one manually from these candidates:lhpit1
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 114 tasks      | elapsed:    2.0s
# Saving LFP data to /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/lfp_data.fif
# Writing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/lfp_data.fif
# [Parallel(n_jobs=-1)]: Done 149 out of 149 | elapsed:    2.6s finished
# Closing /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/lfp_data.fif
# [done]
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/raw_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/raw_ieeg.fif
# [done]

# %% [markdown]
# Even though the pipeline automatically detects channels with high variance compared to the rest of the data, it can still be very useful to scroll through the data and manually click on channels that are bad (or click on automatically bad channels that are,in fact, not bad).
#
# Feel free to be liberal with this. Bad channels are not omitted from analysis; they are simply omitted from being used as references, so they don't spread the 'badness' to other channels.
#
# Manually annotate bad channels for each recording:

# %%
# %matplotlib notebook 
# Note: this does not work in JupyterLAB. Must be done int Jupyter Notebook.

# %%
subj_id = 'MS038'
day = 'Day2'
save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'
mne_data = mne.io.read_raw_fif(f'{save_path}/raw_ieeg.fif', preload=True)
fig = mne_data.plot(start=0, duration=120, n_channels=30, 
                      scalings=mne_data._data.max()/30
                     )
# Out:
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 225535 =      0.000 ...   451.070 secs
# Ready.
# Reading 0 ... 225535  =      0.000 ...   451.070 secs...
# <img src="data:image/png;base64,..." width="1436">

# %%
# Save this manual data
mne_data.save(f'{save_path}/raw_ieeg.fif', overwrite=True)
# Out:
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/raw_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/raw_ieeg.fif
# [done]

# %% [markdown]
# ## Re-reference

# %% [markdown]
# In general, I prefer to do bipolar referencing. I still see good high-frequency activity when doing so. However, you can also do white matter referencing.

# %%
for ix, subj_id in enumerate(subj_ids): 
    site = subj_sites[ix]
    format = subj_formats[ix]
    for day in days:
        # Check if this day is in the dataset:
        if subj_df[day].values[ix] == 0:
            print (f'subject {subj_id} does not have Day 2 data')
            continue
        else:
            print(f'Working on subj {subj_id}')
            # Set paths
            load_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/neural/{day}'
            elec_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/anat/'
            save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'
            # Check if path exists for saving, and if not, make it
            if not os.path.exists(save_path):
                os.makedirs(save_path)

            # electrode files could either be csv or excel
            elec_files = glob(f'{elec_path}/*.csv') + glob(f'{elec_path}/*.xlsx')
            # There should really only be one, so grab it with the zero-index 
            elec_file = elec_files[0]

            # Make MNE file
            mne_data = mne.io.read_raw_fif(f'{save_path}/raw_ieeg.fif', preload=True)


            # Re-reference neural data
            mne_data_reref = lfp_preprocess_utils.ref_mne(mne_data=mne_data, 
                                                          elec_path=elec_file, 
                                                          method='bipolar', 
                                                          site=site)

            # Save this data so that you don't need this step again:
            mne_data_reref.save(f'{save_path}/bp_ref_ieeg.fif', overwrite=True)

            # Should also save out re-referenced elec_file: 
            # Weird issue to note: reference montage could change across days if a new channel becomes noisy (or a noisy channel cleans up!) 

            elec_data = lfp_preprocess_utils.load_elec(elec_file)
            anode_list = [x.split('-')[0] for x in mne_data_reref.ch_names]
            elec_df = elec_data[elec_data.label.str.lower().isin(anode_list)]
            elec_df['label'] =  elec_df.label.apply(lambda x: [a for a in mne_data_reref.ch_names if str(x).lower() in a.split('-')[0]][0])

            # add region to the data frame 
            manual_col = [col for col in elec_df.columns if 'manual' in col.lower()][0]
            all_regions = [] 
            for chan_name in elec_df.label.unique():
                elec_region = analysis_utils.select_rois_picks(elec_df, chan_name, manual_col=manual_col)
                all_regions.append(elec_region) 

            elec_df['salman_region'] = all_regions
            elec_df['hemisphere'] = elec_df.label.apply(lambda x: x[0])

            elec_df.to_csv(f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/{day}_reref_elec_df', index=False)
# Out:
# Working on subj MS012
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Reading 0 ... 394061  =      0.000 ...   788.122 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=53, n_times=394062
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Added the following bipolar channels:
# racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas5-racas6, racas6-racas7, racas8-racas9, racas9-racas10, raglt1-raglt2, raglt2-raglt3, raglt3-raglt4, raglt6-raglt7, raglt7-raglt8, raglt8-raglt9, rals1-rals2, rals2-rals3, rals3-rals4, rals4-rals5, rals8-rals9, rals9-rals10, rals10-rals11, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt7-rhplt8, rmcms3-rmcms4, rmcms4-rmcms5, rmcms7-rmcms8, rmls1-rmls2, rmls2-rmls3, rmls3-rmls4, rmls4-rmls5, rmls7-rmls8, rmls8-rmls9, rmls9-rmls10, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf9-rmolf11, rmtpt1-rmtpt2, rmtpt2-rmtpt3, rmtpt3-rmtpt4, rpls11-rpls12, rpls12-rpls13, rpls13-rpls14, rpls14-rpls15, rpls15-rpls16, rpls16-rpls17, rpls113-rpls114, rpls114-rpls115, rpls115-rpls116
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif
# [done]
# subject MS012 does not have Day 2 data
# Working on subj MS015
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 701187  =      0.000 ...  1402.374 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=22, n_times=701188
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas4, lacas5-lacas6, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lmcms1-lmcms5, lmolf2-lmolf3, lmolf3-lmolf4, lmolf7-lmolf9, raglt1-raglt2, raglt2-raglt3, raist1-raist2, rhplt1-rhplt3, rhplt3-rhplt4, rhplt7-rhplt10, rmcms1-rmcms2, rmcms2-rmcms4, rpmem1-rpmem2, rppem2-rppem5, rppem5-rppem6, rpplem4-rpplem5
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS015
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 697311 =      0.000 ...  1394.622 secs
# Ready.
# Reading 0 ... 697311  =      0.000 ...  1394.622 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=28, n_times=697312
#     Range : 0 ... 697311 =      0.000 ...  1394.622 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas5-lacas6, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lmcms7-lmcms8, lmolf2-lmolf3, lmolf3-lmolf4, lmolf7-lmolf8, lmolf8-lmolf9, raglt1-raglt2, raglt2-raglt3, raglt4-raglt5, raglt5-raglt6, raist1-raist2, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt7-rhplt9, rhplt9-rhplt10, rmcms1-rmcms2, rmcms2-rmcms4, rpmem1-rpmem2, rppem2-rppem5, rppem5-rppem6, rpplem4-rpplem5
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS016
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Reading 0 ... 737811  =      0.000 ...  1475.622 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=52, n_times=737812
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas8-lacas9, lacas9-lacas10, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, lagit9-lagit10, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm6, laimm10-laimm13, laimm13-laimm14, lhpit1-lhpit2, lhpit5-lhpit9, lhpit9-lhpit10, lils2_1-lils1_1, lils1_1-lils2_2, lils2_2-lils2_3, lils2_3-lils1_3, lils1_3-lils2_4, lils2_4-lils1_4, lils1_4-lils1_5, lmcms1-lmcms2, lmcms2-lmcms4, lmcms4-lmcms5, lmcms7-lmcms8, lmls3_1-lmls3_2, lmls3_2-lmls3_3, lmls3_3-lmls3_4, lmls3_4-lmls3_5, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, racas1-racas2, racas8-racas9, racas9-racas11, ragit1-ragit2, ragit2-ragit3, ragit7-ragit8, ragit8-ragit9, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit5, rhpit7-rhpit8, rhpit8-rhpit9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS016
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 346218 =      0.000 ...   692.436 secs
# Ready.
# Reading 0 ... 346218  =      0.000 ...   692.436 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=59, n_times=346219
#     Range : 0 ... 346218 =      0.000 ...   692.436 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas8-lacas9, lacas9-lacas10, lagit2-lagit3, lagit3-lagit5, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, lagit9-lagit10, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm6, laimm10-laimm11, laimm11-laimm12, laimm12-laimm13, laimm13-laimm14, lhpit1-lhpit2, lhpit2-lhpit3, lhpit6-lhpit7, lhpit7-lhpit9, lhpit9-lhpit10, lils2_1-lils1_1, lils1_1-lils2_2, lils2_2-lils1_2, lils1_2-lils2_3, lils2_3-lils1_3, lils1_3-lils2_4, lils2_4-lils1_4, lils1_4-lils1_5, lmcms1-lmcms2, lmcms2-lmcms4, lmcms4-lmcms5, lmcms7-lmcms9, lmls3_1-lmls3_2, lmls3_2-lmls3_3, lmls3_3-lmls3_4, lmls3_4-lmls3_5, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, racas1-racas2, racas8-racas9, racas9-racas10, racas10-racas11, ragit1-ragit2, ragit2-ragit3, ragit7-ragit8, ragit8-ragit9, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit4, rhpit4-rhpit5, rhpit7-rhpit8, rhpit8-rhpit9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS017
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Reading 0 ... 407811  =      0.000 ...   815.622 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=55, n_times=407812
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lacas9-lacas10, laglt1-laglt2, laglt2-laglt3, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, laglt7-laglt8, laglt8-laglt9, lalps1-lalps2, lalps2-lalps3, lalps3-lalps4, lalps9-lalps10, lalps10-lalps11, lalps11-lalps12, lhplt1-lhplt2, lhplt2-lhplt3, lhplt7-lhplt8, lhplt8-lhplt9, lllt1-lllt2, lllt3-lllt4, lllt4-lllt5, lllt5-lllt6, lmcms1-lmcms3, lmcms3-lmcms4, lmcms6-lmcms7, lmlbr1-lmlbr2, lmlbr2-lmlbr3, lmlbr3-lmlbr4, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lpcwr1-lpcwr2, lpcwr7-lpcwr8, lpcwr8-lpcwr9, lpcwr9-lpcwr10, lpcwr10-lpcwr11, lplsp1-lplsp3, ltplt1-ltplt2, ltplt2-ltplt3, ltplt3-ltplt4, ltplt4-ltplt5, ltplt5-ltplt6, ltplt6-ltplt7
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS017
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 220218 =      0.000 ...   440.436 secs
# Ready.
# Reading 0 ... 220218  =      0.000 ...   440.436 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=55, n_times=220219
#     Range : 0 ... 220218 =      0.000 ...   440.436 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lacas9-lacas10, laglt1-laglt2, laglt2-laglt3, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, laglt7-laglt8, lalps1-lalps2, lalps2-lalps3, lalps3-lalps4, lalps9-lalps10, lalps10-lalps11, lalps11-lalps12, lhplt1-lhplt2, lhplt2-lhplt3, lhplt7-lhplt8, lhplt8-lhplt9, lllt1-lllt2, lllt3-lllt4, lllt4-lllt5, lllt5-lllt6, lmcms1-lmcms3, lmcms3-lmcms4, lmcms6-lmcms7, lmlbr1-lmlbr2, lmlbr2-lmlbr3, lmlbr3-lmlbr4, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lpcwr1-lpcwr2, lpcwr6-lpcwr8, lpcwr8-lpcwr9, lpcwr9-lpcwr10, lpcwr10-lpcwr11, lplsp1-lplsp2, lplsp2-lplsp3, ltplt1-ltplt2, ltplt2-ltplt3, ltplt3-ltplt4, ltplt4-ltplt5, ltplt5-ltplt6, ltplt6-ltplt7
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS019
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Reading 0 ... 883624  =      0.000 ...  1767.248 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=61, n_times=883625
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit6-lagit7, lagit7-lagit8, lhpit1-lhpit2, lhpit2-lhpit3, liito3-liito6, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms6-lmcms7, lmoif2-lmoif3, lmoif3-lmoif4, lmoif4-lmoif5, lmoif5-lmoif6, lmoif6-lmoif7, lsppc1-lsppc2, lsppc2-lsppc3, lsppc3-lsppc4, lsppc9-lsppc10, racas5-racas6, racas6-racas7, racas8-racas9, ragit1-ragit2, ragit2-ragit3, ragit3-ragit4, ragit5-ragit6, ragit6-ragit7, rhpit1-rhpit2, rhpit2-rhpit3, rhpit5-rhpit6, rhpit6-rhpit7, rhpit7-rhpit8, riito5-riito6, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms6, rmoif6-rmoif7, rmoif7-rmoif8, rpioc1-rpioc2, rpioc2-rpioc3, rpioc11-rpioc12, rsppc1-rsppc2, rsppc2-rsppc3, rsppc3-rsppc4, rsppc6-rsppc8, rsppc8-rsppc9, rsppc9-rsppc10
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS019
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 461374 =      0.000 ...   922.748 secs
# Ready.
# Reading 0 ... 461374  =      0.000 ...   922.748 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=59, n_times=461375
#     Range : 0 ... 461374 =      0.000 ...   922.748 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit6-lagit7, lhpit1-lhpit2, lhpit2-lhpit3, liito5-liito6, lmcms1-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms6-lmcms7, lmoif2-lmoif3, lmoif3-lmoif4, lmoif4-lmoif5, lmoif5-lmoif6, lmoif6-lmoif7, lmoif7-lmoif8, lmoif8-lmoif9, lsppc1-lsppc2, lsppc2-lsppc3, lsppc3-lsppc4, racas5-racas6, racas6-racas7, racas8-racas9, ragit1-ragit2, ragit2-ragit3, ragit3-ragit4, ragit5-ragit6, rhpit1-rhpit2, rhpit2-rhpit3, rhpit5-rhpit6, rhpit6-rhpit7, rhpit7-rhpit8, riito5-riito6, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms6, rmoif6-rmoif7, rmoif7-rmoif8, rpioc1-rpioc2, rpioc2-rpioc3, rpioc11-rpioc12, rsppc1-rsppc2, rsppc2-rsppc3, rsppc3-rsppc4, rsppc7-rsppc8, rsppc8-rsppc9, rsppc9-rsppc10
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS020
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 592311 =      0.000 ...  1184.622 secs
# Ready.
# Reading 0 ... 592311  =      0.000 ...  1184.622 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=63, n_times=592312
#     Range : 0 ... 592311 =      0.000 ...  1184.622 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas8-lacas9, lagit4-lagit5, lagit5-lagit6, lagit6-lagit7, lalit1-lalit2, lalit2-lalit3, lalit3-lalit4, lalit4-lalit5, lalmf2-lalmf3, lalmf3-lalmf4, lalmf4-lalmf5, lalmf5-lalmf6, lalmf6-lalmf7, lalmf9-lalmf10, lalmf10-lalmf11, lalmf11-lalmf13, lalmf13-lalmf14, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit4, rhpit8-rhpit9, lmcms4-lmcms5, lmcms5-lmcms6, lmcms8-lmcms9, lmolf1-lmolf2, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf8, lmolf8-lmolf9, racas1-racas2, racas2-racas3, racas5-racas6, racas6-racas7, racas8-racas9, racas9-racas10, racas10-racas11, ragit1-ragit2, ragit2-ragit3, ragit6-ragit7, ragit7-ragit8, ralmf2-ralmf3, ralmf3-ralmf4, ralmf4-ralmf5, ralmf5-ralmf6, ralmf9-ralmf10, ralmf10-ralmf11, ralmf11-ralmf12, ralmf13-ralmf14, lhpit1-lhpit2, lhpit2-lhpit3, lhpit3-lhpit5, lhpit5-lhpit6, lhpit6-lhpit7, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS020
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 384780 =      0.000 ...   769.560 secs
# Ready.
# Reading 0 ... 384780  =      0.000 ...   769.560 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=58, n_times=384781
#     Range : 0 ... 384780 =      0.000 ...   769.560 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas8-lacas9, lagit4-lagit5, lagit5-lagit6, lagit6-lagit7, lalit1-lalit2, lalit2-lalit3, lalit3-lalit4, lalit4-lalit5, lalmf2-lalmf3, lalmf3-lalmf4, lalmf4-lalmf5, lalmf5-lalmf6, lalmf6-lalmf7, lalmf9-lalmf11, lalmf11-lalmf12, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit4, rhpit7-rhpit9, lmcms4-lmcms5, lmcms5-lmcms6, lmolf1-lmolf2, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf7-lmolf8, lmolf8-lmolf9, racas1-racas2, racas2-racas3, racas5-racas6, racas6-racas8, racas8-racas9, racas9-racas11, ragit1-ragit2, ragit2-ragit3, ragit6-ragit7, ragit7-ragit8, ralmf1-ralmf2, ralmf2-ralmf3, ralmf3-ralmf4, ralmf4-ralmf5, ralmf5-ralmf6, ralmf9-ralmf10, ralmf10-ralmf11, ralmf11-ralmf12, ralmf13-ralmf14, lhpit1-lhpit2, lhpit2-lhpit3, lhpit3-lhpit4, lhpit5-lhpit6, lhpit6-lhpit7, rmcms1-rmcms2
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS022
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS022/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 1214374 =      0.000 ...  2428.748 secs
# Ready.
# Reading 0 ... 1214374  =      0.000 ...  2428.748 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=36, n_times=1214375
#     Range : 0 ... 1214374 =      0.000 ...  2428.748 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, laglt1-laglt2, laglt2-laglt4, laglt7-laglt8, laglt8-laglt9, laglt9-laglt10, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lhplt4-lhplt5, lhplt7-lhplt8, lhplt8-lhplt9, lhplt9-lhplt10, llesion1-llesion2, llesion2-llesion3, llesion4-llesion5, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmolf1-lmolf2, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, lpcsma1-lpcsma2, lpcsma2-lpcsma3, lpcsma3-lpcsma4, lpcsma5-lpcsma6, lpcsma6-lpcsma7, lpcsma7-lpcsma8, lpcsma8-lpcsma9, lplfo3-lplfo4, lplfo4-lplfo5
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS022/neural/Day1/bp_ref_ieeg.fif
#     Writing channel names to FIF truncated to 15 characters with remapping
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS022/neural/Day1/bp_ref_ieeg.fif
# [done]
# subject MS022 does not have Day 2 data
# Working on subj MS023
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 896499 =      0.000 ...  1792.998 secs
# Ready.
# Reading 0 ... 896499  =      0.000 ...  1792.998 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=88, n_times=896500
#     Range : 0 ... 896499 =      0.000 ...  1792.998 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit5-lagit6, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, laips1-laips2, laips2-laips3, laips3-laips4, laips4-laips5, laips5-laips6, laips6-laips7, laips9-laips10, laips10-laips11, laips11-laips12, lcmpo1-lcmpo3, lcmpo3-lcmpo4, lcmpo4-lcmpo5, lcmpo9-lcmpo11, lcmpo11-lcmpo12, lcmpo12-lcmpo13, lcmpo13-lcmpo14, lhpit1-lhpit2, lhpit2-lhpit3, lhpit6-lhpit7, lhpit7-lhpit10, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmoif5-lmoif6, lmoif6-lmoif7, lmoif7-lmoif8, lpcsma1-lpcsma2, lpcsma2-lpcsma3, lpcsma3-lpcsma4, lpcsma4-lpcsma5, lpcsma5-lpcsma6, racas1-racas2, racas2-racas3, racas7-racas8, racas8-racas9, ragit1-ragit2, ragit2-ragit3, ragit3-ragit4, ragit5-ragit6, ragit6-ragit7, ragit7-ragit8, ragit8-ragit9, rcmpo1-rcmpo2, rcmpo2-rcmpo3, rcmpo3-rcmpo4, rcmpo4-rcmpo5, rcmpo5-rcmpo6, rcmpo6-rcmpo7, rcmpo7-rcmpo8, rcmpo8-rcmpo9, rcmpo12-rcmpo13, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit4, rhpit4-rhpit5, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms5, rmcms5-rmcms6, rmoif1-rmoif2, rmoif2-rmoif3, rmoif3-rmoif4, rmoif4-rmoif5, rmoif5-rmoif6, rmoif6-rmoif7, rmoif7-rmoif8, rmoif8-rmoif9, rmoif9-rmoif10, rpcsma1-rpcsma2, rpcsma2-rpcsma3, rpcsma3-rpcsma4, rpcsma5-rpcsma6, rpcsma6-rpcsma7
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS023
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 734374 =      0.000 ...  1468.748 secs
# Ready.
# Reading 0 ... 734374  =      0.000 ...  1468.748 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=87, n_times=734375
#     Range : 0 ... 734374 =      0.000 ...  1468.748 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit5-lagit6, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, laips1-laips2, laips2-laips3, laips3-laips4, laips4-laips5, laips5-laips6, laips6-laips7, laips9-laips10, laips10-laips11, lcmpo1-lcmpo2, lcmpo2-lcmpo3, lcmpo3-lcmpo4, lcmpo4-lcmpo5, lcmpo9-lcmpo11, lcmpo11-lcmpo12, lhpit1-lhpit2, lhpit2-lhpit3, lhpit6-lhpit7, lhpit7-lhpit8, lhpit8-lhpit9, lhpit9-lhpit10, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmoif5-lmoif6, lpcsma1-lpcsma2, lpcsma2-lpcsma3, lpcsma3-lpcsma4, lpcsma4-lpcsma5, lpcsma5-lpcsma6, racas2-racas3, racas3-racas4, racas4-racas5, racas5-racas6, racas7-racas8, racas8-racas9, ragit1-ragit2, ragit2-ragit3, ragit3-ragit4, ragit5-ragit6, ragit6-ragit7, ragit7-ragit8, ragit8-ragit9, rcmpo1-rcmpo2, rcmpo2-rcmpo3, rcmpo3-rcmpo4, rcmpo4-rcmpo5, rcmpo5-rcmpo6, rcmpo6-rcmpo7, rcmpo7-rcmpo8, rcmpo8-rcmpo9, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit4, rhpit4-rhpit5, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms5, rmcms5-rmcms6, rmoif1-rmoif2, rmoif2-rmoif3, rmoif3-rmoif4, rmoif4-rmoif5, rmoif5-rmoif6, rmoif6-rmoif7, rmoif7-rmoif8, rmoif8-rmoif9, rmoif9-rmoif10, rpcsma1-rpcsma3, rpcsma3-rpcsma4, rpcsma5-rpcsma6, rpcsma6-rpcsma7
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS024
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 356468 =      0.000 ...   712.936 secs
# Ready.
# Reading 0 ... 356468  =      0.000 ...   712.936 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=88, n_times=356469
#     Range : 0 ... 356468 =      0.000 ...   712.936 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, lagit9-lagit10, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm5, laimm5-laimm6, laimm10-laimm11, laimm11-laimm12, laimm12-laimm13, lhpit1-lhpit2, lhpit2-lhpit3, lhpit3-lhpit4, lhpit4-lhpit5, lhpit6-lhpit10, lmcms1-lmcms2, lmcms5-lmcms6, lmcms6-lmcms7, lmcms7-lmcms8, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lptpt1-lptpt2, lptpt2-lptpt3, lptpt3-lptpt4, lptpt4-lptpt5, lptpt5-lptpt6, lptpt6-lptpt7, lptpt7-lptpt8, lptpt8-lptpt9, racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas5-racas6, racas8-racas9, racas9-racas10, ragit1-ragit2, ragit2-ragit3, ragit3-ragit4, ragit6-ragit7, raimm1-raimm2, raimm2-raimm3, raimm3-raimm4, raimm4-raimm5, raimm5-raimm6, raimm12-raimm13, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit4, rhpit4-rhpit5, rhpit6-rhpit7, rhpit7-rhpit8, rhpit8-rhpit9, rhpit9-rhpit10, rhpit10-rhpit11, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms5, rmcms5-rmcms6, rmcms6-rmcms7, rmcms7-rmcms8, rmolf1-rmolf2, rmolf7-rmolf8, rptpt1-rptpt2, rptpt2-rptpt3, rptpt3-rptpt4, rptpt6-rptpt7, rptpt7-rptpt8, rptpt8-rptpt9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS024
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 212405 =      0.000 ...   424.810 secs
# Ready.
# Reading 0 ... 212405  =      0.000 ...   424.810 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=95, n_times=212406
#     Range : 0 ... 212405 =      0.000 ...   424.810 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, lagit9-lagit10, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm5, laimm5-laimm6, laimm10-laimm11, laimm11-laimm12, laimm12-laimm13, laimm13-laimm14, lhpit1-lhpit2, lhpit2-lhpit3, lhpit3-lhpit4, lhpit4-lhpit5, lhpit7-lhpit10, lmcms1-lmcms2, lmcms5-lmcms6, lmcms6-lmcms7, lmcms7-lmcms8, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, lptpt1-lptpt2, lptpt2-lptpt3, lptpt3-lptpt4, lptpt4-lptpt5, lptpt5-lptpt6, lptpt6-lptpt7, lptpt7-lptpt8, lptpt8-lptpt9, lptpt9-lptpt10, racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas5-racas6, racas8-racas9, racas9-racas10, ragit1-ragit2, ragit2-ragit3, ragit3-ragit4, ragit6-ragit7, ragit7-ragit8, raimm1-raimm2, raimm2-raimm3, raimm3-raimm4, raimm4-raimm5, raimm5-raimm6, raimm12-raimm13, raimm13-raimm14, raimm14-raimm15, rhpit1-rhpit2, rhpit2-rhpit3, rhpit3-rhpit4, rhpit4-rhpit5, rhpit6-rhpit7, rhpit7-rhpit8, rhpit8-rhpit9, rhpit9-rhpit10, rhpit10-rhpit11, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms5, rmcms5-rmcms6, rmcms6-rmcms7, rmcms7-rmcms8, rmolf1-rmolf2, rmolf7-rmolf8, rptpt1-rptpt2, rptpt2-rptpt3, rptpt3-rptpt4, rptpt6-rptpt7, rptpt7-rptpt8, rptpt8-rptpt9, rptpt9-rptpt10
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS025
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 534187 =      0.000 ...  1068.374 secs
# Ready.
# Reading 0 ... 534187  =      0.000 ...  1068.374 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=96, n_times=534188
#     Range : 0 ... 534187 =      0.000 ...  1068.374 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, laglt1-laglt2, laglt2-laglt3, laglt3-laglt4, laglt6-laglt7, laglt7-laglt8, laglt8-laglt9, lcmip1-lcmip2, lcmip2-lcmip3, lcmip3-lcmip4, lcmip4-lcmip5, lcmip5-lcmip6, lcmip7-lcmip10, lcmip10-lcmip11, lcmip13-lcmip14, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lhplt4-lhplt5, lhplt8-lhplt9, lhplt9-lhplt10, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms9, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmtpt1-lmtpt2, lmtpt2-lmtpt3, lmtpt5-lmtpt6, lmtpt6-lmtpt7, lmtpt7-lmtpt9, lmtpt9-lmtpt10, lpvnh1-lpvnh2, lpvnh2-lpvnh3, lpvnh3-lpvnh4, lpvnh4-lpvnh5, lpvnh5-lpvnh6, lpvnh6-lpvnh7, lpvnh7-lpvnh8, lpvnh8-lpvnh9, lpvnh9-lpvnh10, lpvnh12-lpvnh13, racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas5-racas6, racas6-racas7, racas7-racas8, racas8-racas9, raglt1-raglt2, raglt2-raglt3, raglt5-raglt6, raglt6-raglt8, raglt8-raglt9, rcmip1-rcmip2, rcmip2-rcmip3, rcmip3-rcmip4, rcmip4-rcmip5, rcmip5-rcmip6, rcmip11-rcmip12, rcmip12-rcmip13, rcmip13-rcmip14, rhplt1-rhplt2, rhplt7-rhplt8, rhplt8-rhplt9, rhplt9-rhplt10, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms5-rmcms6, rmcms6-rmcms7, rmcms7-rmcms8, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rpvnh1-rpvnh2, rpvnh2-rpvnh3, rpvnh3-rpvnh4, rpvnh4-rpvnh5, rpvnh5-rpvnh6, rpvnh8-rpvnh9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS025
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 727061 =      0.000 ...  1454.122 secs
# Ready.
# Reading 0 ... 727061  =      0.000 ...  1454.122 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=93, n_times=727062
#     Range : 0 ... 727061 =      0.000 ...  1454.122 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, laglt1-laglt2, laglt2-laglt3, laglt3-laglt4, laglt6-laglt7, laglt7-laglt8, lcmip1-lcmip2, lcmip2-lcmip3, lcmip3-lcmip4, lcmip4-lcmip5, lcmip5-lcmip6, lcmip13-lcmip14, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lhplt4-lhplt5, lhplt8-lhplt9, lhplt9-lhplt10, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmtpt1-lmtpt2, lmtpt2-lmtpt3, lmtpt5-lmtpt6, lmtpt6-lmtpt7, lmtpt7-lmtpt8, lmtpt8-lmtpt9, lmtpt9-lmtpt10, lpvnh1-lpvnh2, lpvnh2-lpvnh3, lpvnh3-lpvnh4, lpvnh4-lpvnh5, lpvnh5-lpvnh6, lpvnh6-lpvnh7, lpvnh7-lpvnh8, lpvnh8-lpvnh9, lpvnh9-lpvnh10, lpvnh12-lpvnh13, racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas5-racas6, racas6-racas7, racas7-racas8, raglt1-raglt2, raglt2-raglt3, raglt5-raglt6, raglt6-raglt7, raglt7-raglt8, raglt8-raglt9, rcmip1-rcmip2, rcmip2-rcmip3, rcmip3-rcmip4, rcmip4-rcmip5, rcmip5-rcmip6, rcmip11-rcmip12, rcmip12-rcmip13, rcmip13-rcmip14, rhplt1-rhplt2, rhplt7-rhplt8, rhplt8-rhplt9, rhplt9-rhplt10, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms5-rmcms6, rmcms6-rmcms7, rmcms7-rmcms8, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rpvnh1-rpvnh2, rpvnh2-rpvnh3, rpvnh3-rpvnh4, rpvnh4-rpvnh5, rpvnh5-rpvnh6, rpvnh8-rpvnh9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS026
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day1/raw_ieeg.fif...
#     Range : 0 ... 842415 =      0.000 ...  1684.830 secs
# Ready.
# Reading 0 ... 842415  =      0.000 ...  1684.830 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=62, n_times=842416
#     Range : 0 ... 842415 =      0.000 ...  1684.830 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, laglt1-laglt2, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, lcmsp1-lcmsp2, lcmsp2-lcmsp3, lcmsp3-lcmsp4, lcmsp4-lcmsp5, lcmsp5-lcmsp6, lcmsp6-lcmsp7, lcmsp7-lcmsp8, lcmsp11-lcmsp13, lhplt7-lhplt8, lhtoc10-lhtoc11, lhtoc11-lhtoc13, lhtoc13-lhtoc14, lhtoc14-lhtoc15, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, racas5-racas6, racas6-racas7, racas7-racas8, racas9-racas11, raglt1-raglt2, raglt2-raglt3, raglt3-raglt4, raglt4-raglt5, raglt6-raglt7, raglt7-raglt8, rcmsp1-rcmsp2, rcmsp2-rcmsp3, rcmsp3-rcmsp4, rcmsp9-rcmsp10, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt4-rhplt5, rhplt6-rhplt7, rhplt7-rhplt8, rhtoc9-rhtoc12, rmcms2-rmcms3, rmcms3-rmcms4, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rmolf7-rmolf8, rmolf8-rmolf9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS026
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day2/raw_ieeg.fif...
#     Range : 0 ... 566335 =      0.000 ...  1132.670 secs
# Ready.
# Reading 0 ... 566335  =      0.000 ...  1132.670 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=63, n_times=566336
#     Range : 0 ... 566335 =      0.000 ...  1132.670 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas11, laglt1-laglt2, laglt4-laglt7, lcmsp1-lcmsp2, lcmsp2-lcmsp3, lcmsp3-lcmsp4, lcmsp4-lcmsp5, lcmsp5-lcmsp6, lcmsp6-lcmsp7, lcmsp7-lcmsp8, lcmsp11-lcmsp12, lcmsp12-lcmsp13, lhtoc10-lhtoc11, lhtoc11-lhtoc12, lhtoc12-lhtoc14, lhtoc14-lhtoc15, lmcms2-lmcms3, lmcms3-lmcms4, lmolf1-lmolf6, lmolf6-lmolf8, lmolf8-lmolf9, racas5-racas6, racas6-racas7, racas7-racas8, racas10-racas11, raglt1-raglt2, raglt2-raglt3, raglt3-raglt4, raglt4-raglt5, raglt6-raglt7, raglt7-raglt8, raglt8-raglt9, rcmsp1-rcmsp2, rcmsp2-rcmsp3, rcmsp3-rcmsp4, rcmsp9-rcmsp10, rcmsp10-rcmsp11, rcmsp11-rcmsp12, rcmsp12-rcmsp13, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt4-rhplt5, rhplt6-rhplt7, rhplt7-rhplt8, rhplt8-rhplt9, rhplt9-rhplt10, rmcms2-rmcms3, rmcms3-rmcms4, rmcms7-rmcms8, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rmolf7-rmolf8, rmolf8-rmolf9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS028
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS028/neural/Day1/raw_ieeg.fif...
#     Range : 0 ... 609175 =      0.000 ...  1218.350 secs
# Ready.
# Reading 0 ... 609175  =      0.000 ...  1218.350 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=98, n_times=609176
#     Range : 0 ... 609175 =      0.000 ...  1218.350 secs
# Ready.
# Added the following bipolar channels:
# laglt1-laglt2, laglt2-laglt3, laglt3-laglt4, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, laglt7-laglt8, lcmmm1-lcmmm2, lcmmm2-lcmmm3, lcmmm3-lcmmm4, lcmmm4-lcmmm5, lcmmm5-lcmmm6, lcmmm12-lcmmm13, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lhplt4-lhplt5, lhplt8-lhplt9, lacas1-lacas2, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas8-lacas9, laips1-laips2, laips2-laips3, laips3-laips4, laips4-laips5, laips8-laips9, laips9-laips10, laips10-laips11, laips11-laips12, laips12-laips13, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms6-lmcms7, lmcms8-lmcms9, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, raglt1-raglt2, raglt2-raglt3, raglt4-raglt5, raglt5-raglt6, raglt6-raglt7, raglt7-raglt8, rcmmm1-rcmmm2, rcmmm2-rcmmm3, rcmmm3-rcmmm4, rcmmm4-rcmmm5, rcmmm5-rcmmm6, rcmmm6-rcmmm7, rcmmm12-rcmmm13, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt4-rhplt5, rhplt5-rhplt6, rhplt6-rhplt7, rhplt7-rhplt8, rhplt8-rhplt9, rims1-rims2, rims2-rims3, rims3-rims4, rims4-rims5, rims5-rims6, rims8-rims9, rims9-rims10, rims10-rims12, rims12-rims13, rims13-rims14, racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas5-racas6, racas6-racas8, racas8-racas9, racas9-racas10, racas10-racas11, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms6, rmcms7-rmcms8, rmcms8-rmcms9, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rmolf7-rmolf8, rmolf8-rmolf9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS028/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS028/neural/Day1/bp_ref_ieeg.fif
# [done]
# subject MS028 does not have Day 2 data
# Working on subj MS030
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 417968 =      0.000 ...   835.936 secs
# Ready.
# Reading 0 ... 417968  =      0.000 ...   835.936 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=70, n_times=417969
#     Range : 0 ... 417968 =      0.000 ...   835.936 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit5-lagit6, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, lcmmf1-lcmmf2, lcmmf2-lcmmf3, lcmmf3-lcmmf4, lcmmf4-lcmmf5, lcmmf5-lcmmf6, lcmmf10-lcmmf11, lcmmf11-lcmmf12, lcmmf12-lcmmf13, lhpit1-lhpit2, lhpit2-lhpit3, lhpit3-lhpit4, lhpit4-lhpit5, lhpit7-lhpit8, lhpit8-lhpit9, lhpit9-lhpit10, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmoporb1-lmoporb2, lmoporb3-lmoporb4, lmoporb4-lmoporb6, lmoporb6-lmoporb7, lmoporb7-lmoporb8, lpcag1-lpcag2, lpcag2-lpcag3, lpcag7-lpcag8, lpcag8-lpcag9, lpcag9-lpcag10, lpcag10-lpcag11, lpipo1-lpipo2, lpipo2-lpipo3, lpipo5-lpipo6, lpipo6-lpipo7, lpism1-lpism2, lpism2-lpism3, lpism4-lpism5, lpism5-lpism6, lpism6-lpism7, lpism7-lpism8, lprecuoc1-lprecuoc2, lprecuoc2-lprecuoc3, lprecuoc3-lprecuoc4, lprecuoc4-lprecuoc5, lprecuoc7-lprecuoc8, lprecuoc8-lprecuoc9, lprecuoc9-lprecuoc10, lprecusp3-lprecusp4, lprecusp4-lprecusp5, lprecusp9-lprecusp10, lprecusp10-lprecusp11, lsipt1-lsipt2, lsipt2-lsipt3, lsipt6-lsipt7
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day1/bp_ref_ieeg.fif
#     Writing channel names to FIF truncated to 15 characters with remapping
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS030
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 237311 =      0.000 ...   474.622 secs
# Ready.
# Reading 0 ... 237311  =      0.000 ...   474.622 secs...
# Number of electrodes in the mne file is less than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=71, n_times=237312
#     Range : 0 ... 237311 =      0.000 ...   474.622 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas7-lacas8, lacas8-lacas9, lagit1-lagit2, lagit2-lagit3, lagit3-lagit4, lagit4-lagit5, lagit5-lagit6, lagit6-lagit7, lagit7-lagit8, lagit8-lagit9, lcmmf1-lcmmf2, lcmmf2-lcmmf3, lcmmf3-lcmmf4, lcmmf4-lcmmf5, lcmmf5-lcmmf6, lcmmf10-lcmmf11, lcmmf11-lcmmf12, lcmmf12-lcmmf13, lhpit1-lhpit2, lhpit2-lhpit3, lhpit3-lhpit4, lhpit4-lhpit5, lhpit7-lhpit8, lhpit8-lhpit9, lhpit9-lhpit10, lhpit10-lhpit11, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms6-lmcms8, lmoporb1-lmoporb2, lmoporb3-lmoporb4, lmoporb4-lmoporb6, lmoporb6-lmoporb7, lmoporb7-lmoporb8, lpcag1-lpcag2, lpcag2-lpcag3, lpcag7-lpcag9, lpcag9-lpcag10, lpcag10-lpcag11, lpcag11-lpcag12, lpipo1-lpipo2, lpipo2-lpipo3, lpipo5-lpipo6, lpipo6-lpipo7, lpipo7-lpipo8, lpism1-lpism2, lpism2-lpism3, lpism4-lpism5, lpism5-lpism6, lpism6-lpism8, lprecuoc1-lprecuoc2, lprecuoc2-lprecuoc3, lprecuoc3-lprecuoc4, lprecuoc4-lprecuoc5, lprecuoc7-lprecuoc8, lprecuoc8-lprecuoc9, lprecuoc9-lprecuoc10, lprecusp1-lprecusp2, lprecusp3-lprecusp4, lprecusp4-lprecusp6, lprecusp9-lprecusp10, lsipt1-lsipt2, lsipt2-lsipt3
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day2/bp_ref_ieeg.fif
#     Writing channel names to FIF truncated to 15 characters with remapping
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS034
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS034/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 455093 =      0.000 ...   910.186 secs
# Ready.
# Reading 0 ... 455093  =      0.000 ...   910.186 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=76, n_times=455094
#     Range : 0 ... 455093 =      0.000 ...   910.186 secs
# Ready.
# Added the following bipolar channels:
# lacam1-lacam2, lacam2-lacam3, lacam4-lacam5, lacam5-lacam6, lacam7-lacam8, lacam8-lacam9, lacam9-lacam10, lacam10-lacam11, lang2-lang3, lang3-lang4, lang4-lang5, lang5-lang6, lcmmm1-lcmmm2, lcmmm2-lcmmm3, lcmmm3-lcmmm4, lcmmm4-lcmmm5, lcmmm5-lcmmm6, lcmmm9-lcmmm10, lcmmm10-lcmmm11, lcmmm11-lcmmm12, lcmmm12-lcmmm13, lcmmm13-lcmmm14, lcmmm14-lcmmm15, lhplt1-lhplt2, lhplt2-lhplt3, lhplt6-lhplt7, lhplt7-lhplt8, lhplt8-lhplt9, lhplt9-lhplt10, lmcmm1-lmcmm2, lmcmm2-lmcmm3, lmcmm3-lmcmm4, lmcmm4-lmcmm5, lmcmm8-lmcmm10, lmipop1-lmipop2, lmipop2-lmipop3, lmipop7-lmipop8, lmipop8-lmipop9, lmolf1-lmolf2, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, lmolf9-lmolf10, lmolf10-lmolf11, lpcs1f12-lpcs1f13, lpim1l7-lpim1l8, lpvm1f1-lpvm1f2, lpvm1f2-lpvm1f3, lpvm1f3-lpvm1f4, lpvm1f4-lpvm1f5, lpvm1f11-lpvm1f12, lpvm1f12-lpvm1f13, lsiptr1-lsiptr2, lsiptr2-lsiptr3, lsiptr3-lsiptr4, lsiptr4-lsiptr5, lsiptr5-lsiptr6, lsiptr6-lsiptr7, rcmif1-rcmif2, rcmif2-rcmif3, rcmif3-rcmif4, rcmif4-rcmif5, rcmif9-rcmif10, rcmif10-rcmif11, rcmif13-rcmif14, rcmif14-rcmif15, rhplt2-rhplt3, rhplt3-rhplt4, rhplt4-rhplt5, rhplt5-rhplt6, rhplt6-rhplt7, rhplt7-rhplt8, rhplt8-rhplt9, rhplt9-rhplt10
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS034/neural/Day1/bp_ref_ieeg.fif
#     Writing channel names to FIF truncated to 15 characters with remapping
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS034/neural/Day1/bp_ref_ieeg.fif
# [done]
# subject MS034 does not have Day 2 data
# Working on subj MS035
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 611843 =      0.000 ...  1223.686 secs
# Ready.
# Reading 0 ... 611843  =      0.000 ...  1223.686 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=107, n_times=611844
#     Range : 0 ... 611843 =      0.000 ...  1223.686 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas8-lacas9, lacas9-lacas10, laglt1-laglt2, laglt2-laglt3, laglt3-laglt4, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, laglt7-laglt8, laglt8-laglt9, laglt9-laglt10, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm5, laimm5-laimm6, laimm6-laimm7, laimm8-laimm9, laimm9-laimm10, laimm10-laimm11, laimm11-laimm12, laimm12-laimm13, laimm13-laimm14, lcmip1-lcmip2, lcmip2-lcmip3, lcmip3-lcmip4, lcmip4-lcmip5, lcmip7-lcmip8, lcmip8-lcmip9, lcmip9-lcmip10, lcmip10-lcmip11, lcmip11-lcmip12, lcmip12-lcmip13, lcmip13-lcmip14, lhplt1-lhplt2, lhplt3-lhplt4, lhplt4-lhplt5, lhplt5-lhplt6, lhplt6-lhplt7, lhplt7-lhplt8, lhplt8-lhplt9, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms6-lmcms7, lmcms7-lmcms8, lmcms8-lmcms9, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf9-lmolf10, lmolf10-lmolf11, racas1-racas2, racas2-racas3, racas5-racas6, racas6-racas7, racas7-racas8, racas10-racas11, racas11-racas12, raglt1-raglt2, raglt2-raglt3, raglt3-raglt4, raglt5-raglt6, raglt6-raglt7, raglt7-raglt8, raims1-raims2, raims2-raims3, raims3-raims4, raims4-raims5, raims5-raims6, raims6-raims7, raims8-raims9, raims9-raims10, raims10-raims11, raims11-raims12, rcmip1-rcmip2, rcmip2-rcmip3, rcmip3-rcmip4, rcmip4-rcmip5, rcmip7-rcmip8, rcmip8-rcmip9, rcmip12-rcmip13, rhplt1-rhplt2, rhplt2-rhplt4, rhplt5-rhplt6, rhplt6-rhplt7, rhplt7-rhplt8, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms5, rmcms7-rmcms8, rmolf1-rmolf2, rmolf2-rmolf3, rmolf5-rmolf6, rmolf6-rmolf7, rmolf7-rmolf8, rmolf8-rmolf9, rmolf9-rmolf10, rmolf10-rmolf11
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS035
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 307624 =      0.000 ...   615.248 secs
# Ready.
# Reading 0 ... 307624  =      0.000 ...   615.248 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=104, n_times=307625
#     Range : 0 ... 307624 =      0.000 ...   615.248 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas8-lacas9, lacas9-lacas10, laglt1-laglt2, laglt2-laglt3, laglt3-laglt4, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, laglt7-laglt8, laglt8-laglt10, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm5, laimm5-laimm6, laimm6-laimm7, laimm8-laimm9, laimm9-laimm10, laimm10-laimm11, laimm11-laimm12, laimm12-laimm13, laimm13-laimm14, lcmip1-lcmip2, lcmip2-lcmip3, lcmip3-lcmip4, lcmip4-lcmip5, lcmip7-lcmip8, lcmip8-lcmip9, lcmip9-lcmip10, lcmip10-lcmip11, lcmip11-lcmip12, lcmip12-lcmip14, lhplt1-lhplt2, lhplt3-lhplt4, lhplt4-lhplt5, lhplt5-lhplt6, lhplt6-lhplt7, lhplt7-lhplt8, lhplt8-lhplt9, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms6-lmcms7, lmcms7-lmcms8, lmcms8-lmcms9, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf9-lmolf10, lmolf10-lmolf11, racas1-racas2, racas2-racas3, racas5-racas6, racas6-racas7, racas7-racas8, racas10-racas11, racas11-racas12, raglt1-raglt2, raglt2-raglt3, raglt3-raglt4, raglt5-raglt6, raglt6-raglt7, raglt7-raglt8, raims1-raims2, raims2-raims3, raims3-raims4, raims4-raims5, raims5-raims6, raims6-raims7, raims8-raims9, raims9-raims11, raims11-raims12, raims12-raims13, rcmip1-rcmip2, rcmip2-rcmip3, rcmip3-rcmip4, rcmip4-rcmip5, rcmip7-rcmip8, rcmip8-rcmip9, rcmip12-rcmip13, rhplt1-rhplt2, rhplt2-rhplt4, rhplt5-rhplt6, rhplt6-rhplt7, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms4-rmcms5, rmcms6-rmcms8, rmolf1-rmolf2, rmolf2-rmolf3, rmolf5-rmolf6, rmolf6-rmolf7, rmolf7-rmolf8, rmolf8-rmolf9, rmolf9-rmolf10, rmolf10-rmolf11
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS036
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 446780 =      0.000 ...   893.560 secs
# Ready.
# Reading 0 ... 446780  =      0.000 ...   893.560 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=80, n_times=446781
#     Range : 0 ... 446780 =      0.000 ...   893.560 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas5-lacas6, lacas6-lacas7, lacas9-lacas10, lacas10-lacas11, laglt1-laglt2, laglt3-laglt4, laglt4-laglt5, laglt5-laglt6, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm5, laimm8-laimm9, laimm9-laimm10, laimm10-laimm11, laimm11-laimm12, laimm12-laimm13, lhplt2-lhplt3, lhplt3-lhplt4, lhplt8-lhplt9, lhplt9-lhplt10, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms7-lmcms8, lmcms8-lmcms9, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, lmolf9-lmolf10, lmolf10-lmolf11, racas1-racas2, racas8-racas9, racas9-racas10, racas10-racas11, racas11-racas12, raglt1-raglt2, raglt2-raglt3, raglt4-raglt5, raglt5-raglt6, raglt6-raglt7, raglt7-raglt8, raglt8-raglt9, raglt9-raglt10, raimm1-raimm2, raimm2-raimm3, raimm3-raimm4, raimm4-raimm5, raimm8-raimm9, raimm9-raimm11, raimm11-raimm12, raimm12-raimm13, raimm13-raimm14, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt5-rhplt6, rhplt6-rhplt7, rhplt7-rhplt8, rhplt8-rhplt9, rhplt9-rhplt10, rmcms1-rmcms2, rmcms6-rmcms7, rmcms7-rmcms8, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rmolf8-rmolf9, rmolf9-rmolf10
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS036
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 199218 =      0.000 ...   398.436 secs
# Ready.
# Reading 0 ... 199218  =      0.000 ...   398.436 secs...
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=80, n_times=199219
#     Range : 0 ... 199218 =      0.000 ...   398.436 secs
# Ready.
# Added the following bipolar channels:
# lacas1-lacas2, lacas5-lacas6, lacas6-lacas7, lacas9-lacas10, lacas10-lacas11, laglt1-laglt2, laglt3-laglt4, laglt4-laglt5, laglt5-laglt6, laimm1-laimm2, laimm2-laimm3, laimm3-laimm4, laimm4-laimm5, laimm8-laimm9, laimm9-laimm10, laimm10-laimm11, laimm11-laimm12, laimm12-laimm13, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lhplt8-lhplt9, lhplt9-lhplt10, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms7-lmcms8, lmcms8-lmcms9, lmolf1-lmolf2, lmolf2-lmolf3, lmolf3-lmolf4, lmolf4-lmolf5, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, lmolf9-lmolf10, lmolf10-lmolf11, racas1-racas2, racas8-racas9, racas9-racas10, racas10-racas11, racas11-racas12, raglt1-raglt2, raglt2-raglt3, raglt4-raglt5, raglt5-raglt6, raglt6-raglt7, raglt7-raglt8, raglt8-raglt10, raimm1-raimm2, raimm2-raimm3, raimm3-raimm4, raimm4-raimm5, raimm8-raimm9, raimm9-raimm10, raimm10-raimm11, raimm11-raimm12, raimm12-raimm13, raimm13-raimm14, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt5-rhplt6, rhplt6-rhplt8, rhplt8-rhplt9, rhplt9-rhplt10, rmcms1-rmcms2, rmcms6-rmcms7, rmcms7-rmcms8, rmolf1-rmolf2, rmolf2-rmolf3, rmolf3-rmolf4, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rmolf8-rmolf9, rmolf9-rmolf10
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day2/bp_ref_ieeg.fif
# [done]
# Working on subj MS038
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 539391 =      0.000 ...  1078.782 secs
# Ready.
# Reading 0 ... 539391  =      0.000 ...  1078.782 secs...
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=74, n_times=539392
#     Range : 0 ... 539391 =      0.000 ...  1078.782 secs
# Ready.
# Added the following bipolar channels:
# laglt1-laglt2, laglt2-laglt3, laglt3-laglt4, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, laglt7-laglt8, laglt8-laglt9, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lhplt5-lhplt6, lhplt6-lhplt7, lhplt7-lhplt8, lhplt8-lhplt9, lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas9-lacas10, lammf1-lammf2, lammf2-lammf3, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms6-lmcms7, lmcms7-lmcms8, lmcms8-lmcms9, lmcms9-lmcms10, lmolf3-lmolf4, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, raglt1-raglt2, raglt2-raglt3, raglt5-raglt6, raglt6-raglt7, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt5-rhplt6, rhplt6-rhplt7, rhplt7-rhplt10, racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas9-racas10, raimm1-raimm2, raimm4-raimm5, raimm11-raimm12, raimm12-raimm13, raimm13-raimm14, raimm14-raimm15, raimm15-raimm16, rammf1-rammf2, rammf2-rammf3, rammf4-rammf5, rammf5-rammf6, rammf8-rammf9, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms7-rmcms8, rmcms8-rmcms9, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rmolf8-rmolf9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/bp_ref_ieeg.fif
# [done]
# Working on subj MS038
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/raw_ieeg.fif...
# Isotrak not found
#     Range : 0 ... 225535 =      0.000 ...   451.070 secs
# Ready.
# Reading 0 ... 225535  =      0.000 ...   451.070 secs...
# Number of electrodes in the mne file is greater than the number of electrodes in the localization file
# sEEG channel type selected for re-referencing
# Creating RawArray with float64 data, n_channels=76, n_times=225536
#     Range : 0 ... 225535 =      0.000 ...   451.070 secs
# Ready.
# Added the following bipolar channels:
# laglt1-laglt2, laglt2-laglt3, laglt3-laglt4, laglt4-laglt5, laglt5-laglt6, laglt6-laglt7, laglt7-laglt9, lhplt1-lhplt2, lhplt2-lhplt3, lhplt3-lhplt4, lhplt5-lhplt6, lhplt6-lhplt7, lhplt7-lhplt8, lhplt8-lhplt9, lacas1-lacas2, lacas2-lacas3, lacas3-lacas4, lacas4-lacas5, lacas5-lacas6, lacas6-lacas7, lacas9-lacas10, lammf1-lammf2, lammf2-lammf3, lmcms1-lmcms2, lmcms2-lmcms3, lmcms3-lmcms4, lmcms4-lmcms5, lmcms5-lmcms6, lmcms6-lmcms7, lmcms7-lmcms8, lmcms8-lmcms9, lmcms9-lmcms10, lmolf3-lmolf4, lmolf5-lmolf6, lmolf6-lmolf7, lmolf7-lmolf8, lmolf8-lmolf9, raglt1-raglt2, raglt2-raglt3, raglt5-raglt6, raglt6-raglt7, rhplt1-rhplt2, rhplt2-rhplt3, rhplt3-rhplt4, rhplt5-rhplt6, rhplt6-rhplt7, rhplt7-rhplt8, rhplt8-rhplt9, rhplt9-rhplt10, racas1-racas2, racas2-racas3, racas3-racas4, racas4-racas5, racas9-racas10, racas10-racas11, raimm1-raimm2, raimm4-raimm5, raimm11-raimm12, raimm12-raimm13, raimm13-raimm14, raimm14-raimm15, raimm15-raimm16, rammf1-rammf2, rammf2-rammf3, rammf4-rammf5, rammf5-rammf6, rammf8-rammf9, rmcms1-rmcms2, rmcms2-rmcms3, rmcms3-rmcms4, rmcms7-rmcms8, rmcms8-rmcms9, rmolf4-rmolf5, rmolf5-rmolf6, rmolf6-rmolf7, rmolf8-rmolf9
# Overwriting existing file.
# Writing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/bp_ref_ieeg.fif
# Closing /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/bp_ref_ieeg.fif
# [done]

# %%
len(mne_data_reref.ch_names)
# Out:
# 47

# %%
elec_df.shape
# Out:
# (47, 18)

# %%
# %matplotlib notebook 
# Note: this does not work in JupyterLAB. Must be done int Jupyter Notebook.

# %%
subj_id = 'MS025'
day = 'Day1'
save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'
mne_data_reref = mne.io.read_raw_fif(f'{save_path}/bp_ref_ieeg.fif', preload=True)
# Out:
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 534187 =      0.000 ...  1068.374 secs
# Ready.
# Reading 0 ... 534187  =      0.000 ...  1068.374 secs...

# %%
fig = mne_data_reref.plot(start=0, duration=10, n_channels=60, 
                      scalings=mne_data_reref._data.max()/20
                     )
# Out:
# <MNEBrowseFigure size 1436x1436 with 4 Axes>

# %% [markdown]
# Look at the power spectra for specific channels. Click the channels to see their names (e.g. if you need to pick out a bad ugly channel)

# %%
mne_data_reref.compute_psd().plot()
# Out:
# Effective window size : 4.096 (s)
# <img src="data:image/png;base64,..." width="1000">
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
#  - mne_data: a Raw mne object, where the data has been loaded, filtered for line noise, searched for bad channels, parsed for different data types, and resampled if necessary.
#
#  - mne_data_reref: an mne object containing re-referenced data (either white matter or bipolar)
#
# If you have ran the preprocessing above, load the data instead:

# %%
mne_data_reref.save(f'{save_path}/bp_ref_ieeg.fif', overwrite=True)

# %%
# %matplotlib inline

# %% [markdown]
# ## Load neural data

# %%
elec_dict = {f'{x}': {f'{y}': [] for y in days} for x in subj_ids}
mne_dict = {f'{x}': {f'{y}': [] for y in days} for x in subj_ids}
photodiode_dict = {f'{x}': {f'{y}': [] for y in days} for x in subj_ids}

# %%
for ix, subj_id in enumerate(subj_ids): 
    for day in days:
        # Check if this day is in the dataset:
        if subj_df[day].values[ix] == 0:
            print (f'subject {subj_id} does not have Day 2 data')
            continue
        else:
            # Set paths
            load_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/neural/{day}'
            save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'

            # Get electrode df 
            elec_df = pd.read_csv(f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/{day}_reref_elec_df')

            mne_data_reref = mne.io.read_raw_fif(f'{save_path}/bp_ref_ieeg.fif', preload=True)

            photodiode_data = mne.io.read_raw_fif(f'{load_path}/photodiode.fif', preload=True)

            # Append to list 
            mne_dict[subj_id][day].append(mne_data_reref)

            photodiode_dict[subj_id][day].append(photodiode_data)

            elec_dict[subj_id][day].append(elec_df)
# Out:
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Reading 0 ... 394061  =      0.000 ...   788.122 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS012/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 807039 =      0.000 ...   788.124 secs
# Ready.
# Reading 0 ... 807039  =      0.000 ...   788.124 secs...
# subject MS012 does not have Day 2 data
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 701187  =      0.000 ...  1402.374 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS015/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1436031 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 1436031  =      0.000 ...  1402.374 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 697311 =      0.000 ...  1394.622 secs
# Ready.
# Reading 0 ... 697311  =      0.000 ...  1394.622 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS015/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1428095 =      0.000 ...  1394.624 secs
# Ready.
# Reading 0 ... 1428095  =      0.000 ...  1394.624 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Reading 0 ... 737811  =      0.000 ...  1475.622 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS016/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1511039 =      0.000 ...  1475.624 secs
# Ready.
# Reading 0 ... 1511039  =      0.000 ...  1475.624 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 346218 =      0.000 ...   692.436 secs
# Ready.
# Reading 0 ... 346218  =      0.000 ...   692.436 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS016/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 709055 =      0.000 ...   692.437 secs
# Ready.
# Reading 0 ... 709055  =      0.000 ...   692.437 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Reading 0 ... 407811  =      0.000 ...   815.622 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS017/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 835199 =      0.000 ...   815.624 secs
# Ready.
# Reading 0 ... 835199  =      0.000 ...   815.624 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 220218 =      0.000 ...   440.436 secs
# Ready.
# Reading 0 ... 220218  =      0.000 ...   440.436 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS017/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 451007 =      0.000 ...   440.437 secs
# Ready.
# Reading 0 ... 451007  =      0.000 ...   440.437 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Reading 0 ... 883624  =      0.000 ...  1767.248 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS019/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1809663 =      0.000 ...  1767.249 secs
# Ready.
# Reading 0 ... 1809663  =      0.000 ...  1767.249 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 461374 =      0.000 ...   922.748 secs
# Ready.
# Reading 0 ... 461374  =      0.000 ...   922.748 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS019/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 944895 =      0.000 ...   922.749 secs
# Ready.
# Reading 0 ... 944895  =      0.000 ...   922.749 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 592311 =      0.000 ...  1184.622 secs
# Ready.
# Reading 0 ... 592311  =      0.000 ...  1184.622 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS020/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1213055 =      0.000 ...  1184.624 secs
# Ready.
# Reading 0 ... 1213055  =      0.000 ...  1184.624 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 384780 =      0.000 ...   769.560 secs
# Ready.
# Reading 0 ... 384780  =      0.000 ...   769.560 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS020/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 788031 =      0.000 ...   769.562 secs
# Ready.
# Reading 0 ... 788031  =      0.000 ...   769.562 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS022/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 1214374 =      0.000 ...  2428.748 secs
# Ready.
# Reading 0 ... 1214374  =      0.000 ...  2428.748 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS022/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 2487039 =      0.000 ...  2428.749 secs
# Ready.
# Reading 0 ... 2487039  =      0.000 ...  2428.749 secs...
# subject MS022 does not have Day 2 data
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 896499 =      0.000 ...  1792.998 secs
# Ready.
# Reading 0 ... 896499  =      0.000 ...  1792.998 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS023/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1836031 =      0.000 ...  1792.999 secs
# Ready.
# Reading 0 ... 1836031  =      0.000 ...  1792.999 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 734374 =      0.000 ...  1468.748 secs
# Ready.
# Reading 0 ... 734374  =      0.000 ...  1468.748 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS023/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1503999 =      0.000 ...  1468.749 secs
# Ready.
# Reading 0 ... 1503999  =      0.000 ...  1468.749 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 356468 =      0.000 ...   712.936 secs
# Ready.
# Reading 0 ... 356468  =      0.000 ...   712.936 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS024/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 730047 =      0.000 ...   712.937 secs
# Ready.
# Reading 0 ... 730047  =      0.000 ...   712.937 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 212405 =      0.000 ...   424.810 secs
# Ready.
# Reading 0 ... 212405  =      0.000 ...   424.810 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS024/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 435007 =      0.000 ...   424.812 secs
# Ready.
# Reading 0 ... 435007  =      0.000 ...   424.812 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 534187 =      0.000 ...  1068.374 secs
# Ready.
# Reading 0 ... 534187  =      0.000 ...  1068.374 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS025/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1094015 =      0.000 ...  1068.374 secs
# Ready.
# Reading 0 ... 1094015  =      0.000 ...  1068.374 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 727061 =      0.000 ...  1454.122 secs
# Ready.
# Reading 0 ... 727061  =      0.000 ...  1454.122 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS025/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1489023 =      0.000 ...  1454.124 secs
# Ready.
# Reading 0 ... 1489023  =      0.000 ...  1454.124 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 842415 =      0.000 ...  1684.830 secs
# Ready.
# Reading 0 ... 842415  =      0.000 ...  1684.830 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS026/neural/Day1/photodiode.fif...
#     Range : 0 ... 3369663 =      0.000 ...  1684.832 secs
# Ready.
# Reading 0 ... 3369663  =      0.000 ...  1684.832 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 566335 =      0.000 ...  1132.670 secs
# Ready.
# Reading 0 ... 566335  =      0.000 ...  1132.670 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS026/neural/Day2/photodiode.fif...
#     Range : 0 ... 2265343 =      0.000 ...  1132.671 secs
# Ready.
# Reading 0 ... 2265343  =      0.000 ...  1132.671 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS028/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 609175 =      0.000 ...  1218.350 secs
# Ready.
# Reading 0 ... 609175  =      0.000 ...  1218.350 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS028/neural/Day1/photodiode.fif...
#     Range : 0 ... 2436703 =      0.000 ...  1218.351 secs
# Ready.
# Reading 0 ... 2436703  =      0.000 ...  1218.351 secs...
# subject MS028 does not have Day 2 data
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 417968 =      0.000 ...   835.936 secs
# Ready.
# Reading 0 ... 417968  =      0.000 ...   835.936 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS030/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 855999 =      0.000 ...   835.937 secs
# Ready.
# Reading 0 ... 855999  =      0.000 ...   835.937 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day2/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 237311 =      0.000 ...   474.622 secs
# Ready.
# Reading 0 ... 237311  =      0.000 ...   474.622 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS030/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 486015 =      0.000 ...   474.624 secs
# Ready.
# Reading 0 ... 486015  =      0.000 ...   474.624 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS034/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 455093 =      0.000 ...   910.186 secs
# Ready.
# Reading 0 ... 455093  =      0.000 ...   910.186 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS034/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 932031 =      0.000 ...   910.187 secs
# Ready.
# Reading 0 ... 932031  =      0.000 ...   910.187 secs...
# subject MS034 does not have Day 2 data
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 611843 =      0.000 ...  1223.686 secs
# Ready.
# Reading 0 ... 611843  =      0.000 ...  1223.686 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS035/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 1253055 =      0.000 ...  1223.687 secs
# Ready.
# Reading 0 ... 1253055  =      0.000 ...  1223.687 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 307624 =      0.000 ...   615.248 secs
# Ready.
# Reading 0 ... 307624  =      0.000 ...   615.248 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS035/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 630015 =      0.000 ...   615.249 secs
# Ready.
# Reading 0 ... 630015  =      0.000 ...   615.249 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 446780 =      0.000 ...   893.560 secs
# Ready.
# Reading 0 ... 446780  =      0.000 ...   893.560 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS036/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 915007 =      0.000 ...   893.562 secs
# Ready.
# Reading 0 ... 915007  =      0.000 ...   893.562 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 199218 =      0.000 ...   398.436 secs
# Ready.
# Reading 0 ... 199218  =      0.000 ...   398.436 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS036/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 407999 =      0.000 ...   398.437 secs
# Ready.
# Reading 0 ... 407999  =      0.000 ...   398.437 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 539391 =      0.000 ...  1078.782 secs
# Ready.
# Reading 0 ... 539391  =      0.000 ...  1078.782 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day1/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 2157567 =      0.000 ...  1078.784 secs
# Ready.
# Reading 0 ... 2157567  =      0.000 ...  1078.784 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day2/bp_ref_ieeg.fif...
#     Range : 0 ... 225535 =      0.000 ...   451.070 secs
# Ready.
# Reading 0 ... 225535  =      0.000 ...   451.070 secs...
# Opening raw data file /sc/arion/projects/guLab/Salman/EMU/MS038/neural/Day2/photodiode.fif...
# Isotrak not found
#     Range : 0 ... 902143 =      0.000 ...   451.072 secs
# Ready.
# Reading 0 ... 902143  =      0.000 ...   451.072 secs...

# %% [markdown]
#  - mne_dict: a dictionary containing all of your subjects' re-referenced mne data
#
#  - photodiode_dict: a dictionary containing all of your subjects' photodiode data
#
#  - elec_dict: a dictionary containing the paths to your subjects' electrode data

# %% [markdown]
# ## Sync behavioral and neural data

# %% [markdown]
# Here, we perform a critical step: computing the time offset between the computer that recorded the neural data and the laptop that featured the experiment.
#
# The function here only requires a **subset** of detected sync signals (i.e. photodiode deflections) to be detected to successfully compute this offset.

# %% [markdown]
# First, some of the photodiode data can be a bit crummy, which you need to clean up in an idiosyncratic way... ugh

# %%
subj_id = 'MS015'
day = 'Day1'
temp_diode = photodiode_dict[subj_id][day][0]._data[0, :]
temp_diode[900000:] = np.nanmin(temp_diode)
# photodiode_dict[subj_id][day][0]._data = temp_diode[0:420000]
# temp_diode[temp_diode>.13] = 0.1
photodiode_dict[subj_id][day][0]._data = temp_diode


subj_id = 'MS022'
day = 'Day1'
temp_diode = np.abs(photodiode_dict[subj_id][day][0]._data[0,:])
temp_diode[temp_diode>.13] = 0.1
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS026'
day = 'Day1'
temp_diode = photodiode_dict[subj_id][day][0]._data[0,:]
temp_diode[temp_diode>4000] = 0
temp_diode[temp_diode<-4000] = 0
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS028'
day = 'Day1'
temp_diode = photodiode_dict[subj_id][day][0]._data[0,:]
temp_diode[temp_diode>4000] = 0
temp_diode[temp_diode<-3000] = 0
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS030'
day = 'Day1'
temp_diode = photodiode_dict[subj_id][day][0]._data[0,:]
temp_diode[temp_diode>0.005] = 0.005
temp_diode[temp_diode>-0.002] = 0.004
temp_diode[temp_diode<-0.004] = -0.004
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS034'
day = 'Day1'
temp_diode = -(photodiode_dict[subj_id][day][0]._data[0,:])
temp_diode[temp_diode>-0.225] = -0.225
temp_diode[temp_diode>-0.2375] = -0.225
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS035'
day = 'Day1'
temp_diode = -(photodiode_dict[subj_id][day][0]._data[0,:])
temp_diode[temp_diode>-0.25] = -0.25
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS035'
day = 'Day2'
temp_diode = -(photodiode_dict[subj_id][day][0]._data[0,:])
temp_diode[temp_diode>-0.25] = -0.25
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS036'
day = 'Day1'
temp_diode = -(photodiode_dict[subj_id][day][0]._data[0,:])
photodiode_dict[subj_id][day][0]._data = temp_diode


subj_id = 'MS036'
day = 'Day2'
temp_diode = -(photodiode_dict[subj_id][day][0]._data[0,:])
photodiode_dict[subj_id][day][0]._data = temp_diode

subj_id = 'MS038'
day = 'Day1'
temp_diode = (photodiode_dict[subj_id][day][0]._data[0,:])
# temp_diode[temp_diode<0] = 0
# photodiode_dict[subj_id][day][0]._data = temp_diode

# %% [markdown]
# Now, let's compute the slopes and offsets

# %%
slopes = {f'{x}': {f'{y}': [] for y in days} for x in subj_ids}
offsets = {f'{x}': {f'{y}': [] for y in days} for x in subj_ids}


for ix, subj_id in enumerate(subj_ids):
    for day in days:
        # Check if this day is in the dataset:
        if subj_df[day].values[ix] == 0:
            print (f'subject {subj_id} does not have Day 2 data')
            continue
        else:
            print(f'Working on subj {subj_id}')
            # Load the behavioral timestamps: 
            behav_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/behav/{day}'
            temp_df = pd.read_csv(glob(f'{behav_path}/*.csv')[0], index_col=None, header=0)
            # Load in the timestamps pertaining to your sync. If your task had a square pop up, for example, grab the times for that square's appearance from the behavioral logs.
            # Below, I do this for my own task's Psychopy output, but yours is probably coded differently. 
            beh_ts = temp_df[temp_df.keys()[temp_df.keys().str.startswith('sync') & temp_df.keys().str.endswith('started')]].values
            beh_ts = beh_ts[~np.isnan(beh_ts)] 

            # Synchronize to the photodiode or whatever your neural sync signal is
            height = 1
            windSize = 15
            smoothSize = 11
            
            # Can sometimes help to set some parameters manually for individuals with bad signal 
            if subj_id in ['MS015']:
                if day == 'Day1':
                    height = 1
                    windSize = 35
                    smoothSize = 10
                elif day == 'Day2':
                    height = 1.5
                    windSize = 20
                    smoothSize = 11                  
            if subj_id in ['MS020']:
                if day == 'Day1':
                    height = 1.5
#             if subj_id in ['MS030']:
#                 if day == 'Day1':
#                     height = 1.5
            if subj_id in ['MS038']:
                if day == 'Day1':
                    height = 1
                    windSize = 35
#             elif subj_id in ['MS022', 'MS025', 'MS026']:
#                 if day == 'Day1':
#                     height = 2
#             elif subj_id in ['MS028']:
#                 if day == 'Day1':
#                     height = 0.5            
            slope, offset = sync_utils.synchronize_data(beh_ts, 
                                                        photodiode_dict[subj_id][day][0], 
                                                        smoothSize=smoothSize, windSize=windSize, height=height)

#             print(slope)
#             print(offset)
            slopes[subj_id][day].append(slope)
            offsets[subj_id][day].append(offset)
# Out:
# Working on subj MS012
# 28 blocks
# ............................
#
# found matches for 150 of 428 pulses
# subject MS012 does not have Day 2 data
# Working on subj MS015
# 10 blocks
# ..........
#
# found matches for 105 of 380 pulses
# Working on subj MS015
# 8 blocks
# ........
#
# found matches for 160 of 164 pulses
# Working on subj MS016
# 28 blocks
# ............................
#
# found matches for 345 of 426 pulses
# Working on subj MS016
# 9 blocks
# .........
#
# found matches for 75 of 139 pulses
# Working on subj MS017
# 32 blocks
# ................................
#
# found matches for 135 of 493 pulses
# Working on subj MS017
# Working on subj MS019
# 11 blocks
# ...........
#
# found matches for 60 of 165 pulses
# Working on subj MS019
# 10 blocks
# ..........
#
# found matches for 135 of 164 pulses
# Working on subj MS020
# 117 blocks
# .....................................................................................................................
#
# found matches for 120 of 1760 pulses
# Working on subj MS020
# 10 blocks
# ..........
#
# found matches for 120 of 162 pulses
# Working on subj MS022
# 65 blocks
# .................................................................
#
# found matches for 135 of 986 pulses
# subject MS022 does not have Day 2 data
# Working on subj MS023
# 30 blocks
# ..............................
#
# found matches for 300 of 464 pulses
# Working on subj MS023
# 37 blocks
# .....................................
#
# found matches for 150 of 562 pulses
# Working on subj MS024
# 40 blocks
# ........................................
#
# found matches for 105 of 612 pulses
# Working on subj MS024
# Working on subj MS025
# 31 blocks
# ...............................
#
# found matches for 285 of 469 pulses
# Working on subj MS025
# 77 blocks
# .............................................................................
#
# found matches for 30 of 1159 pulses
# Working on subj MS026
# 254 blocks
# ..............................................................................................................................................................................................................................................................
#
# found matches for 135 of 3814 pulses
# Working on subj MS026
# 11 blocks
# ...........
#
# found matches for 90 of 169 pulses
# Working on subj MS028
# 160 blocks
# ................................................................................................................................................................
#
# found matches for 120 of 2414 pulses
# subject MS028 does not have Day 2 data
# Working on subj MS030
# 826 blocks
# ..........................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................................
#
# found matches for 15 of 12393 pulses
# Working on subj MS030
# Working on subj MS034
# 39 blocks
# .......................................
#
# found matches for 60 of 593 pulses
# subject MS034 does not have Day 2 data
# Working on subj MS035
# 31 blocks
# ...............................
#
# found matches for 270 of 470 pulses
# Working on subj MS035
# 12 blocks
# ............
#
# found matches for 135 of 187 pulses
# Working on subj MS036
# 31 blocks
# ...............................
#
# found matches for 300 of 474 pulses
# Working on subj MS036
# 10 blocks
# ..........
#
# found matches for 120 of 164 pulses
# Working on subj MS038
# 33 blocks
# .................................
#
# found matches for 140 of 1184 pulses
# Working on subj MS038
# 11 blocks
# ...........
#
# found matches for 150 of 174 pulses

# %%
# %matplotlib inline

# %%
# Save the sync info
file = f'{base_dir}/projects/guLab/Salman/EMU/slopes.json'
with open(file, 'wb') as f: 
    pickle.dump(slopes, f, pickle.HIGHEST_PROTOCOL)
    f.close()
file = f'{base_dir}/projects/guLab/Salman/EMU/offsets.json'
with open(file, 'wb') as f: 
    pickle.dump(offsets, f, pickle.HIGHEST_PROTOCOL)
    f.close()

# %%
# slopes['MS038']['Day1'] = [] 
# offsets['MS038']['Day1'] = []

# %% [markdown]
#  - slopes: a dictionary containing the slopes (should be ~ 1) for each subject
#  - offsets: a dictionary containing the offsets for each subject

# %% [markdown]
# Note: The slope should always be VERY close to 1! If you run into issues with syncing downstream, come back and check this...

# %% [markdown]
# ## Load the sync data

# %%
# Load the sync info
file = f'{base_dir}/projects/guLab/Salman/EMU/slopes.json'
with open(file, 'rb') as f: 
    slopes = pickle.load(f)
file = f'{base_dir}/projects/guLab/Salman/EMU/offsets.json'
with open(file, 'rb') as f: 
    offsets = pickle.load(f)

# %%
slopes
# Out:
# {'MS012': {'Day1': [0.9999892560991055], 'Day2': []},
#  'MS015': {'Day1': [1.0007136066766493], 'Day2': [1.0000113058767246]},
#  'MS016': {'Day1': [0.9999796222645818], 'Day2': [0.9999941256028682]},
#  'MS017': {'Day1': [1.0006201052188766], 'Day2': [1.0020229387555606]},
#  'MS019': {'Day1': [1.0000061316533204], 'Day2': [1.0000127069109512]},
#  'MS020': {'Day1': [1.0000157003334416], 'Day2': [1.0000078981670395]},
#  'MS022': {'Day1': [1.000003245457805], 'Day2': []},
#  'MS023': {'Day1': [1.0000599483155062], 'Day2': [0.9999975710236938]},
#  'MS024': {'Day1': [0.9999978254650277], 'Day2': [1.008323718673507]},
#  'MS025': {'Day1': [1.0001245919264934], 'Day2': [1.000013653594013]},
#  'MS026': {'Day1': [1.000008023619669], 'Day2': [0.9999917842323772]},
#  'MS028': {'Day1': [0.999370696622421], 'Day2': []},
#  'MS030': {'Day1': [0.9999782427874625], 'Day2': [1.0026312356140472]},
#  'MS034': {'Day1': [1.005172825240541], 'Day2': []},
#  'MS035': {'Day1': [0.9999793832257485], 'Day2': [0.9998973878167973]},
#  'MS036': {'Day1': [1.0000075143218692], 'Day2': [0.9999864147649115]},
#  'MS038': {'Day1': [1.0000006348432624], 'Day2': [1.000016040318219]},
#  'UI001': {'Day1': [1.0000071238942903], 'Day2': []},
#  'UI002': {'Day1': [1.0591319451355077], 'Day2': []},
#  'UI003': {'Day1': [0.9926839920924223], 'Day2': []},
#  'UI004': {'Day1': [1.0007682438100625], 'Day2': []}}

# %% [markdown]
# Note: I have two different tasks in one experiment
#
# 1) Decision-making
# 2) Memory
#
# Furthermore, the memory task is split into Day 1 and Day 2. So really, it's like having three tasks in one. So I will be performing the same steps repeatedly.

# %% [markdown]
# ## Make epochs (decision-making task)

# %% [markdown]
# Make epochs and remove IEDs. Currently just doing this for one example period - when subjects receive feedback.

# %%
# set some windows of interest 

buf = 1.0 # this is the buffer before and after that we use to limit edge effects for TFRs

IED_args = {'peak_thresh':4,
           'closeness_thresh':0.25, 
           'width_thresh':0.2}

# evs = ['gamble_start', 'feedback_start', 'baseline_start']
evs = {'gamble_start': [-1.0, 0.],
       'feedback_start': [0., 1.5],
       'baseline_start': [0., 0.75]}

# evs = {'feedback_start': [-0.5, 1.5]}


# add behavioral times of interest 
for subj_id in subj_ids:
    for day in ['Day1']:
        # Set paths
        load_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/neural/{day}'
        save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'

        epochs_all_evs = {f'{x}': np.nan for x in evs}
        for event in evs.keys():
            pre = evs[event][0]
            post = evs[event][1]
            fixed_baseline = None
            behav_times = learn_df[(learn_df.participant==subj_id)][event]

            epochs = lfp_preprocess_utils.make_epochs(load_path=f'{save_path}/bp_ref_ieeg.fif', 
                                                      slope=slopes[subj_id][day][0], offset=offsets[subj_id][day][0], 
                                                      behav_name=event, behav_times=behav_times,
                                                      ev_start_s=pre, ev_end_s=post, buf_s=1, downsamp_factor=None, IED_args=IED_args)

            
            epochs_all_evs[event] = epochs
            epochs_all_evs[event].save(f'{save_path}/{event}-epo.fif', overwrite=True)
# Out:
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Reading 0 ... 394061  =      0.000 ...   788.122 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    8.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.7s finished
# Used Annotations descriptions: ['gamble_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 53 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Reading 0 ... 394061  =      0.000 ...   788.122 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.6s finished
# Used Annotations descriptions: ['feedback_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1751 original time points ...
# 0 bad epochs dropped
# Adding metadata with 53 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Reading 0 ... 394061  =      0.000 ...   788.122 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.6s finished
# Used Annotations descriptions: ['baseline_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 53 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI001/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 468351 =      0.000 ...   936.702 secs
# Ready.
# Reading 0 ... 468351  =      0.000 ...   936.702 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.7s finished
# Used Annotations descriptions: ['gamble_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 48 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI001/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 468351 =      0.000 ...   936.702 secs
# Ready.
# Reading 0 ... 468351  =      0.000 ...   936.702 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.6s finished
# Used Annotations descriptions: ['feedback_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1751 original time points ...
# 0 bad epochs dropped
# Adding metadata with 48 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI001/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 468351 =      0.000 ...   936.702 secs
# Ready.
# Reading 0 ... 468351  =      0.000 ...   936.702 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.7s finished
# Used Annotations descriptions: ['baseline_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 48 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 701187  =      0.000 ...  1402.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.5s finished
# Used Annotations descriptions: ['gamble_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 22 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 701187  =      0.000 ...  1402.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.5s finished
# Used Annotations descriptions: ['feedback_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1751 original time points ...
# 0 bad epochs dropped
# Adding metadata with 22 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 701187  =      0.000 ...  1402.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.5s finished
# Used Annotations descriptions: ['baseline_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 22 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Reading 0 ... 737811  =      0.000 ...  1475.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.4s finished
# Used Annotations descriptions: ['gamble_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 52 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Reading 0 ... 737811  =      0.000 ...  1475.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.5s finished
# Used Annotations descriptions: ['feedback_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1751 original time points ...
# 0 bad epochs dropped
# Adding metadata with 52 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Reading 0 ... 737811  =      0.000 ...  1475.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.3s finished
# Used Annotations descriptions: ['baseline_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 52 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Reading 0 ... 407811  =      0.000 ...   815.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.6s finished
# Used Annotations descriptions: ['gamble_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 55 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Reading 0 ... 407811  =      0.000 ...   815.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.6s finished
# Used Annotations descriptions: ['feedback_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1751 original time points ...
# 0 bad epochs dropped
# Adding metadata with 55 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Reading 0 ... 407811  =      0.000 ...   815.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.6s finished
# Used Annotations descriptions: ['baseline_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 55 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI002/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 977663 =      0.000 ...  1955.326 secs
# Ready.
# Reading 0 ... 977663  =      0.000 ...  1955.326 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 111 out of 115 | elapsed:    4.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    4.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 111 out of 115 | elapsed:    3.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    3.1s finished
# Used Annotations descriptions: ['gamble_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 115 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI002/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 977663 =      0.000 ...  1955.326 secs
# Ready.
# Reading 0 ... 977663  =      0.000 ...  1955.326 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 111 out of 115 | elapsed:    4.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    4.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 111 out of 115 | elapsed:    3.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    3.3s finished
# Used Annotations descriptions: ['feedback_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1751 original time points ...
# 0 bad epochs dropped
# Adding metadata with 115 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI002/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 977663 =      0.000 ...  1955.326 secs
# Ready.
# Reading 0 ... 977663  =      0.000 ...  1955.326 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 111 out of 115 | elapsed:    4.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    4.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 111 out of 115 | elapsed:    3.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    3.1s finished
# Used Annotations descriptions: ['baseline_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 115 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Reading 0 ... 883624  =      0.000 ...  1767.248 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.5s finished
# Used Annotations descriptions: ['gamble_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 61 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Reading 0 ... 883624  =      0.000 ...  1767.248 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  57 out of  61 | elapsed:    1.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.5s finished
# Used Annotations descriptions: ['feedback_start']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1751 original time points ...
# 0 bad epochs dropped
# Adding metadata with 61 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Reading 0 ... 883624  =      0.000 ...  1767.248 secs...

# %% [markdown]
# If you want to extract a dictionary of good and bad epochs by channel, use the following:

# %%
good_epochs, bad_epochs = lfp_preprocess_utils.get_bad_epochs_by_chan(epochs)

# %%
# annot_df = ev_epochs._annotations.to_data_frame()

# %%
# bad_df = annot_df[annot_df.description.str.startswith('bad')].reset_index()

# %%
# bad_df.ch_names = bad_df.ch_names.apply(lambda x: x[0])

# %%
# bad_df['event'] = np.nan
# bad_times_s = _annotations_starts_stops(mne_data_reref, ['BAD'])[0] / mne_data_reref.info['sfreq']

# %% [markdown]
# ## Make epochs (memory)

# %%
# set some windows of interest 

buf = 1.0 # this is the buffer before and after that we use to limit edge effects for TFRs

IED_args = {'peak_thresh':4,
           'closeness_thresh':0.25, 
           'width_thresh':0.2}

evs = {'recog_time': [-1.0, 0.0],
       'baseline_start_mem': [0, 0.75]}


# add behavioral times of interest 
for ix, subj_id in enumerate(subj_ids):
    for day in ['Day1']: 
        if (day=='Day2') & (subj_days[ix]==0):
            continue
        else:
            # Set paths
            load_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/neural/{day}'
            save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'

            epochs_all_evs = {f'{x}': np.nan for x in evs}
            for event in evs.keys():
                pre = evs[event][0]
                post = evs[event][1]
                fixed_baseline = None
                behav_times = combined_df[(combined_df.participant==subj_id) & (combined_df.condition==day)][event]

    #             baseline_times = combined_df[(combined_df.participant==subj_id) & (combined_df.condition==f'{day}')].dropna(subset='trials_gamble').baseline_start_mem

                epochs = lfp_preprocess_utils.make_epochs(load_path=f'{save_path}/bp_ref_ieeg.fif', 
                                                          slope=slopes[subj_id][day][0], offset=offsets[subj_id][day][0], 
                                                          behav_name=event, behav_times=behav_times,
                                                          ev_start_s=pre, ev_end_s=post, buf_s=1, downsamp_factor=None, IED_args=IED_args)


                epochs_all_evs[event] = epochs
                epochs_all_evs[event].save(f'{save_path}/{event}-epo.fif', overwrite=True)
# Out:
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Reading 0 ... 394061  =      0.000 ...   788.122 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:   10.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.6s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 53 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS012/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 394061 =      0.000 ...   788.122 secs
# Ready.
# Reading 0 ... 394061  =      0.000 ...   788.122 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    0.6s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 53 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI001/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 468351 =      0.000 ...   936.702 secs
# Ready.
# Reading 0 ... 468351  =      0.000 ...   936.702 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.7s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 48 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI001/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 468351 =      0.000 ...   936.702 secs
# Ready.
# Reading 0 ... 468351  =      0.000 ...   936.702 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    0.6s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 48 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 701187  =      0.000 ...  1402.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.5s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 22 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS015/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 701187 =      0.000 ...  1402.374 secs
# Ready.
# Reading 0 ... 701187  =      0.000 ...  1402.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    0.5s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 22 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Reading 0 ... 737811  =      0.000 ...  1475.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.1s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.2s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 52 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS016/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 737811 =      0.000 ...  1475.622 secs
# Ready.
# Reading 0 ... 737811  =      0.000 ...  1475.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    1.4s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 52 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Reading 0 ... 407811  =      0.000 ...   815.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.6s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 55 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS017/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 407811 =      0.000 ...   815.622 secs
# Ready.
# Reading 0 ... 407811  =      0.000 ...   815.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    0.6s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 55 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Reading 0 ... 883624  =      0.000 ...  1767.248 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.6s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 61 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS019/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 883624 =      0.000 ...  1767.248 secs
# Ready.
# Reading 0 ... 883624  =      0.000 ...  1767.248 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    1.5s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 61 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 592311 =      0.000 ...  1184.622 secs
# Ready.
# Reading 0 ... 592311  =      0.000 ...  1184.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  63 out of  63 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  63 out of  63 | elapsed:    1.0s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 63 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS020/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 592311 =      0.000 ...  1184.622 secs
# Ready.
# Reading 0 ... 592311  =      0.000 ...  1184.622 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  63 out of  63 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  63 out of  63 | elapsed:    0.9s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 63 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS022/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 1214374 =      0.000 ...  2428.748 secs
# Ready.
# Reading 0 ... 1214374  =      0.000 ...  2428.748 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  36 | elapsed:    1.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    1.5s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 36 columns
# Overwriting existing file.
# Overwriting existing file.
#     Writing channel names to FIF truncated to 15 characters with remapping
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS022/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 1214374 =      0.000 ...  2428.748 secs
# Ready.
# Reading 0 ... 1214374  =      0.000 ...  2428.748 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  36 | elapsed:    1.0s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  32 out of  36 | elapsed:    1.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    1.5s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 36 columns
# Overwriting existing file.
# Overwriting existing file.
#     Writing channel names to FIF truncated to 15 characters with remapping
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 896499 =      0.000 ...  1792.998 secs
# Ready.
# Reading 0 ... 896499  =      0.000 ...  1792.998 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  88 | elapsed:    2.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    2.1s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 88 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS023/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 896499 =      0.000 ...  1792.998 secs
# Ready.
# Reading 0 ... 896499  =      0.000 ...  1792.998 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    1.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  84 out of  88 | elapsed:    2.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    2.2s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 88 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI003/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 577023 =      0.000 ...  1154.046 secs
# Ready.
# Reading 0 ... 577023  =      0.000 ...  1154.046 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  71 out of  75 | elapsed:    1.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:    1.2s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 75 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI003/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 577023 =      0.000 ...  1154.046 secs
# Ready.
# Reading 0 ... 577023  =      0.000 ...  1154.046 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  71 out of  75 | elapsed:    1.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  75 out of  75 | elapsed:    1.3s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 75 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 356468 =      0.000 ...   712.936 secs
# Ready.
# Reading 0 ... 356468  =      0.000 ...   712.936 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    0.8s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 35 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 88 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS024/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 356468 =      0.000 ...   712.936 secs
# Ready.
# Reading 0 ... 356468  =      0.000 ...   712.936 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    0.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    9.1s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 35 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 35 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 88 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 534187 =      0.000 ...  1068.374 secs
# Ready.
# Reading 0 ... 534187  =      0.000 ...  1068.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    1.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  92 out of  96 | elapsed:    1.6s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    1.6s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 96 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS025/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 534187 =      0.000 ...  1068.374 secs
# Ready.
# Reading 0 ... 534187  =      0.000 ...  1068.374 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  92 out of  96 | elapsed:    1.6s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    1.7s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 96 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 842415 =      0.000 ...  1684.830 secs
# Ready.
# Reading 0 ... 842415  =      0.000 ...  1684.830 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:    1.5s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 62 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS026/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 842415 =      0.000 ...  1684.830 secs
# Ready.
# Reading 0 ... 842415  =      0.000 ...  1684.830 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:    1.5s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 62 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS028/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 609175 =      0.000 ...  1218.350 secs
# Ready.
# Reading 0 ... 609175  =      0.000 ...  1218.350 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:    1.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  94 out of  98 | elapsed:    1.5s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:    1.5s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 98 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS028/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 609175 =      0.000 ...  1218.350 secs
# Ready.
# Reading 0 ... 609175  =      0.000 ...  1218.350 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done  94 out of  98 | elapsed:    1.5s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:    1.6s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 98 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 417968 =      0.000 ...   835.936 secs
# Ready.
# Reading 0 ... 417968  =      0.000 ...   835.936 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    0.8s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 70 columns
# Overwriting existing file.
# Overwriting existing file.
#     Writing channel names to FIF truncated to 15 characters with remapping
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS030/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 417968 =      0.000 ...   835.936 secs
# Ready.
# Reading 0 ... 417968  =      0.000 ...   835.936 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    0.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  70 out of  70 | elapsed:    0.7s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 70 columns
# Overwriting existing file.
# Overwriting existing file.
#     Writing channel names to FIF truncated to 15 characters with remapping
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI004/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 614271 =      0.000 ...  1228.542 secs
# Ready.
# Reading 0 ... 614271  =      0.000 ...  1228.542 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 111 out of 111 | elapsed:    1.6s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 111 out of 111 | elapsed:    2.0s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 111 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/UI004/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 614271 =      0.000 ...  1228.542 secs
# Ready.
# Reading 0 ... 614271  =      0.000 ...  1228.542 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 111 out of 111 | elapsed:    1.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 107 out of 111 | elapsed:    1.9s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 111 out of 111 | elapsed:    1.9s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 111 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS034/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 455093 =      0.000 ...   910.186 secs
# Ready.
# Reading 0 ... 455093  =      0.000 ...   910.186 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:    1.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:    1.1s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 79 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 79 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 76 columns
# Overwriting existing file.
# Overwriting existing file.
#     Writing channel names to FIF truncated to 15 characters with remapping
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS034/neural/Day1/bp_ref_ieeg.fif...
#     Reading extended channel information
#     Range : 0 ... 455093 =      0.000 ...   910.186 secs
# Ready.
# Reading 0 ... 455093  =      0.000 ...   910.186 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  76 out of  76 | elapsed:    1.0s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 76 columns
# Overwriting existing file.
# Overwriting existing file.
#     Writing channel names to FIF truncated to 15 characters with remapping
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 611843 =      0.000 ...  1223.686 secs
# Ready.
# Reading 0 ... 611843  =      0.000 ...  1223.686 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 107 out of 107 | elapsed:    1.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 107 out of 107 | elapsed:    2.0s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 107 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS035/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 611843 =      0.000 ...  1223.686 secs
# Ready.
# Reading 0 ... 611843  =      0.000 ...  1223.686 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 107 out of 107 | elapsed:    1.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 107 out of 107 | elapsed:    2.0s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 107 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 446780 =      0.000 ...   893.560 secs
# Ready.
# Reading 0 ... 446780  =      0.000 ...   893.560 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    1.0s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 80 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS036/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 446780 =      0.000 ...   893.560 secs
# Ready.
# Reading 0 ... 446780  =      0.000 ...   893.560 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  80 out of  80 | elapsed:    1.0s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 80 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 539391 =      0.000 ...  1078.782 secs
# Ready.
# Reading 0 ... 539391  =      0.000 ...  1078.782 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:    0.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:    1.1s finished
# Used Annotations descriptions: ['recog_time']
# Not setting metadata
# 74 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 74 events and 1501 original time points ...
# 0 bad epochs dropped
# Adding metadata with 74 columns
# Overwriting existing file.
# Overwriting existing file.
# Opening raw data file /sc/arion/projects/guLab/Salman/EphysAnalyses/MS038/neural/Day1/bp_ref_ieeg.fif...
#     Range : 0 ... 539391 =      0.000 ...  1078.782 secs
# Ready.
# Reading 0 ... 539391  =      0.000 ...  1078.782 secs...
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 25 - 80 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 25.00
# - Lower transition bandwidth: 6.25 Hz (-6 dB cutoff frequency: 21.88 Hz)
# - Upper passband edge: 80.00 Hz
# - Upper transition bandwidth: 20.00 Hz (-6 dB cutoff frequency: 90.00 Hz)
# - Filter length: 265 samples (0.530 s)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:    0.9s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done  74 out of  74 | elapsed:    1.1s finished
# Used Annotations descriptions: ['baseline_start_mem']
# Not setting metadata
# 80 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 80 events and 1376 original time points ...
# 0 bad epochs dropped
# Adding metadata with 74 columns
# Overwriting existing file.
# Overwriting existing file.

# %% [markdown]
# ## Extract the relevant dataframes and plots for one subject before expanding to group analysis:

# %% [markdown]
# We probably want to produce two dataframes:
#
# 1. Electrode-level: This is the highest-level dataframe, which is computing electrode-level traits for all trials, which cannot be computed at the trial-level, as well as parsing by conditions. Should be mergeable with the next level.
#
# 2. Trial-level: This is the second-level dataframe, which is computing trial-level traits for each electrode.
#
# 3. Timewise: This is the third-level dataframe, used sparingly. It will include timepoints for time-specific results.

# %% [markdown]
# This involves running a series of analyses:
#
#
# 0. Compute power spectrum
#
# 1. FOOOF (all trials)
#
# 2. FOOOF (conditions)
#
# 3. TFR
#
# 4. eBOSC
#
# 5. catch-22 traits (ML)
#
# 6. ripple algorithm (TBD)
#
# 7. temporally-resolved regression (optional - timewise)
#
# 8. connectivity
#
# 9. pac
#
#
# Each analysis also has the potential to generate both data objects as well as plots that we might want to sve. We should make it optional as to whether all these exhaust fumes should actually be saved or not.

# %% [markdown]
# ## Time-series characteristics (Catch-22)

# %% [markdown]
# Here, we aim to characterize some linear AND non-linear explanatory features of our timeseries. I don't use this much yet but useful for ML approaches.

# %%
# import warnings
# warnings.filterwarnings('ignore')

# %%
# ev_dict = {'feedback_start': [-0.5, 1.5]}

# #        'baseline_start': [0, 0.75]
# # 'gamble_start': [-1.0, 0.5],

# # Define peak_width, peak_height, peak_threshold, max_n_peaks
# FOOOF_kwargs = {'peak_width_limits': [1, 8], 
#                'min_peak_height': 0.1,
#                 'peak_threshold': 1.,
#                 'max_n_peaks': 3,
#                'freq_range': [1, 30]}
 
# # Define our frequency bands of interest
# band_dict = {'delta' : [1, 4],
#                'theta' : [4, 8],
#                'alpha' : [8, 13],
#                'beta' : [13, 30]}

# conditions = ['rpe>0',
#              'rpe<1']


# # For now, let's go channel-by-channel, otherwise I would define our ROIs as such:
# rois = ['hippocampus', 'amygdala', 'insula', 'parahippocampal', 'entorhinal', 'anterior_cingulate']

# all_dfs = []

# for ix, subj_id in enumerate(subj_ids):
#     # Load one person's data 
#     for day in ['Day1']:
#         load_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/neural/{day}'
#         for event in ev_dict.keys():   
#             # filepath = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/scratch/FOOOF/{event}'
#             # if not os.path.exists(f'{filepath}/plots'):
#             #     os.makedirs(f'{filepath}/plots')
#             # if not os.path.exists(f'{filepath}/dfs'):
#             #     os.makedirs(f'{filepath}/dfs')

#             mne_data_reref = mne.read_epochs(f'{load_path}/{event}-epo.fif', preload=True)
#             # Put in the behavioral data for the different tasks
#             evs_for_dm_only = behav_data[(behav_data.participant==subj_id)]
#             evs_for_dm_and_mem = combined_df[(combined_df.participant==subj_id)]
#             mne_data_reref.metadata = evs_for_dm_only
            
#             if evs_for_dm_and_mem.shape[0]<160: 
#                 print('not enough recalls') 
#                 continue

#             save_path = f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}'
#             # Get electrode df 
#             elec_path = f'{base_dir}/projects/guLab/Salman/EMU/{subj_id}/anat/'
#             # electrode files could either be csv or excel
#             elec_files = glob(f'{elec_path}/*.csv') + glob(f'{elec_path}/*.xlsx')
#             # There should really only be one 
#             elec_file = elec_files[0]

#         #     # IF Picking ROI: Revise labelling in electrode csv in order to match the re-referenced channel names 
#             elec_data = lfp_preprocess_utils.load_elec(elec_file)
#             anode_list = [x.split('-')[0] for x in mne_data_reref.ch_names]
#             elec_df = elec_data[elec_data.label.str.lower().isin(anode_list)]
#             elec_df['label'] =  elec_df.label.apply(lambda x: [a for a in mne_data_reref.ch_names if str(x).lower() in a.split('-')[0]][0])

#             all_aucs = []
#             all_chans = [] 
#             all_regions = [] 

#             progress_bar = tqdm(mne_data_reref.ch_names, ascii=True, desc='Computing catch-22 classifier')

#             for chan in progress_bar: 

#                 dfs = []

#                 # Can pick the epoch depending on the event being selected
#                 chan_epochs = mne_data_reref.copy().pick_channels([chan])

#                 region = analysis_utils.select_rois_picks(elec_df, chan)

#                 df_all = [] 
#                 for ix, signal in enumerate(chan_epochs._data.squeeze()):
#                     catch_22_df = analysis_utils.hctsa_signal_features(signal).astype(float)
#                     df_all.append(catch_22_df)

#                 catch_22_names = list(catch_22_df.keys().values.astype('str'))

#                 df_all = pd.concat(df_all)
#                 df_all['recognition'] = evs_for_dm_only.merge(evs_for_dm_and_mem,on='img_path').hits.astype(int).tolist()
#                 df_all['chan'] = chan
#                 df_all['subj'] = subj_id 
#                 df_all['region'] = region
#                 all_dfs.append(df_all)
# #                 # zdf = df_all.apply(zscore)

# #                 X = df_all[catch_22_names].values
# #                 y = evs_for_dm_only.merge(evs_for_dm_and_mem,on='img_path').hits.astype(int).tolist()



# #                 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# #                 from sklearn import preprocessing
# #                 scaler = preprocessing.StandardScaler().fit(X_train)
# #                 X_scaled = scaler.transform(X_train)

# #                 # Create a logistic regression model
# #                 model = LogisticRegression()

# #                 # Train the model using the training data
# #                 model.fit(X_scaled, y_train)

# #                 predictions = model.predict(X_test)


# #                 # Calculate AUC-ROC score
# #                 auc_roc = roc_auc_score(y_test, predictions)

# #                 # print("AUC-ROC Score:", auc_roc)

# #                 all_aucs.append(auc_roc)
#                 # all_chans.append(chan)
#                 # all_regions.append(region)

#             # res_df = pd.DataFrame(columns=['subj', 'region', 'chan', 'auc'])
#             # res_df['auc'] = all_aucs
#             # res_df['subj'] = subj_id 
#             # res_df['chan'] = all_chans
#             # res_df['region'] = all_regions
            
#             # df_all['chan'] = all_chans
#             # df_all['region'] = all_regions
#             # df_all['subj'] = subj_id 


#             # all_dfs.append(df_all)

#                 # zdf = df_all.apply(zscore)
# #                     zdf['recognition'] = evs_for_dm_only.merge(evs_for_dm_and_mem,on='img_path').hits.astype(int).tolist()

# #                     # try:
# #                     #     model = smf.logit(formula=formula, data=zdf).fit()
# #                     # except ValueError:
# #                     #     continue

# #                     # param_df = pd.DataFrame(model.params.iloc[1:]).T
# #                     zdf['chan'] = chan
# #                     zdf['subj'] = subj_id
# #                     zdf['region'] = region 
# #                     all_feat_dfs.append(zdf)
                    
# all_pt_dfs = pd.concat(all_dfs)

# %%
# # Load the feature names: 
# catch_22_names = ['DN_HistogramMode_5',
#  'DN_HistogramMode_10',
#  'CO_f1ecac',
#  'CO_FirstMin_ac',
#  'CO_HistogramAMI_even_2_5',
#  'CO_trev_1_num',
#  'MD_hrv_classic_pnn40',
#  'SB_BinaryStats_mean_longstretch1',
#  'SB_TransitionMatrix_3ac_sumdiagcov',
#  'PD_PeriodicityWang_th0_01',
#  'CO_Embed2_Dist_tau_d_expfit_meandiff',
#  'IN_AutoMutualInfoStats_40_gaussian_fmmi',
#  'FC_LocalSimple_mean1_tauresrat',
#  'DN_OutlierInclude_p_001_mdrmd',
#  'DN_OutlierInclude_n_001_mdrmd',
#  'SP_Summaries_welch_rect_area_5_1',
#  'SB_BinaryStats_diff_longstretch0',
#  'SB_MotifThree_quantile_hh',
#  'SC_FluctAnal_2_rsrangefit_50_1_logi_prop_r1',
#  'SC_FluctAnal_2_dfa_50_1_2_logi_prop_r1',
#  'SP_Summaries_welch_rect_centroid',
#  'FC_LocalSimple_mean3_stderr']

# # Make two for loops

# # Loop through every unique subj
# # Within each subject, loop through every unique chan 

# import statsmodels as sm
# from statsmodels.stats.outliers_influence import variance_inflation_factor as vif
# from statsmodels.tools.tools import add_constant
# from scipy.stats import zscore 
# import pandas as pd
# import numpy as np 

# for subj in aarushi_df.subj.unique():
#     subj_df = aarushi_df[aarushi_df.subj==subj]
#     for chan in subj_df.chan.unique():
#         # electrode-specific df:
#         chan_df = subj_df[subj_df.chan==chan]

#         # Compute the variance inflation factor. Remove any factors that exceed 5 according to 'vif_info'
#         X = add_constant(chan_df[catch_22_names])
#         vif_info = pd.Series([vif(X.values, i) 
#                        for i in range(X.shape[1])], 
#                       index=X.columns)

#         remove_feats = list(vif_info[vif_info>5].index)
#         remaining_feats = [x for x in catch_22_names if x not in remove_feats]

#         # Zscore the data: 
#         zdf = chan_df[remaining_feats].apply(zscore)

#         # Assuming X contains your features and y contains your labels
#         X = zdf.values
#         y = chan_df.recognition.values

#         # Calculate class weights
#         class_counts = np.bincount(y)  # Count the number of samples in each class
#         total_samples = len(y)
#         class_weights = total_samples / (len(class_counts) * class_counts)

#         # Assign weights to each sample in y_train
#         weights_train = class_weights[y]

#         # Add a constant column to the features matrix
#         X_with_const = sm.add_constant(X)

#         # Create and fit the weighted logistic regression model
#         model = sm.Logit(y, X_with_const, weights=weights_train)
#         result = model.fit()

#         # get the predictive value for each feature 
#         model_weights = result.params
#         # TODO: add them to a dataframe with the correct name from 'remaining_feats' as well as the channel and subject name 

#         # Get the overall predictive value of the electrode/channel
#         adjusted_r_squared = result.prsquared
#         # TODO: add them to a dataframe with the correct channel and subject name



#         # TODO: save this all in a sensibly organized dataframe

#         # TODO: Explore the data with some plots
# Out:
# array([ 0.48456554, -0.42723561,  1.32584894, -0.40747306,  1.46329272,
#         0.42261349,  0.0712579 , -0.22912419, -0.35365817, -0.4947393 ,
#         0.5865606 ,  0.50494659, -0.18856001,  0.22221856])

# %%
# all_pt_dfs.to_csv(f'{base_dir}/projects/guLab/Salman/EphysAnalyses/catch_22_df.csv',
#                   index=False)

# %% [markdown]
# ## Background stuff: # of electrodes per region, brain plots, table generation.

# %% [markdown]
# Before we get started with the cool analyses we have to do the boring stuff like validating our electrode numbers per region per subject, making brain plots (or making a csv for brain plotting in MATLAB), and generating a table that can be published in a manuscript:

# %%
# First, consolidate all electrode dfs, collapse the dumb manual columns into one column
all_elec_dfs = []
# subj_ids = ['UI001', 'UI002', 'UI003', 'UI004']
for subj_id in subj_ids: 
    elec_df = pd.read_csv(f'{base_dir}/projects/guLab/Salman/EphysAnalyses/{subj_id}/Day1_reref_elec_df')
    elec_df['participant'] = subj_id
    all_elec_dfs.append(elec_df)
all_elec_dfs = pd.concat(all_elec_dfs).reset_index() 


# Get rid of bad patients: 
all_elec_dfs = all_elec_dfs[~all_elec_dfs['participant'].isin(['MS024', 'MS034', 'MS038', 'UI002'])]
# # Collapse columns with 'manual' in the column name
# manual_cols = [col for col in all_elec_dfs.columns if 'manual' in col.lower()]
# all_elec_dfs['collapsed_manual'] = all_elec_dfs[manual_cols].apply(lambda row: ', '.join(row.dropna()), axis=1)

# # Drop original manual columns
# all_elec_dfs = all_elec_dfs.drop(columns=manual_cols)

# # make sure this is filled with 'np.nan' other than where there is an entry
# all_elec_dfs.collapsed_manual[all_elec_dfs['collapsed_manual']==''] = np.nan

# # Second, add a region label to each electrode that combines across all atlases and manual inputs: 
# all_elec_dfs['salman_region'] = np.nan
# all_regions = [] 
# for subj_id in subj_ids: 
#     subj_elec_df = all_elec_dfs[all_elec_dfs.participant==subj_id]
#     for chan_name in subj_elec_df.label.unique():
#         elec_region = analysis_utils.select_rois_picks(subj_elec_df, chan_name, manual_col='collapsed_manual')
#         all_regions.append(elec_region) 
# all_elec_dfs['salman_region'] = all_regions

# %%
print_df = all_elec_dfs[['participant', 'salman_region']]
print_df = print_df[print_df.salman_region!='Unknown']

# Create a pivot table
pivot_table = print_df.pivot_table(index='participant', columns='salman_region', aggfunc='size', fill_value=0)

# Reset the index to make participant a column again (optional)
pivot_table.reset_index(inplace=True)

# Add a row for column-wise sum excluding the 'participant' column
pivot_table.loc['Total'] = pivot_table.drop('participant', axis=1).sum()

# %%
pivot_table.to_csv(f'{base_dir}/projects/guLab/Salman/EMU/total_elecs_per_subj.csv', index=False)
all_elec_dfs.to_csv(f'{base_dir}/projects/guLab/Salman/EMU/full_elec_df_UI.csv', index=False)

# %%
# # here's the stuff we left out:
# all_elec_dfs[all_elec_dfs['salman_region']=='Unknown'].collapsed_manual.value_counts().head(10)

# %%
# will help you visualize your distribution of electrodes across regions across people 
def make_pretty(styler):
    styler.background_gradient(axis=None, vmin=0, vmax=10, cmap="Spectral_r")
    return styler

styled_df = pivot_table.style.pipe(make_pretty)

# %%
styled_df
# Out:
# <style type="text/css">
# #T_9988d_row0_col1, #T_9988d_row0_col11, #T_9988d_row0_col21, #T_9988d_row1_col5, #T_9988d_row2_col3, #T_9988d_row2_col5, #T_9988d_row5_col11, #T_9988d_row5_col20, #T_9988d_row8_col3, #T_9988d_row8_col5, #T_9988d_row8_col21, #T_9988d_row9_col1, #T_9988d_row10_col16, #T_9988d_row11_col15, #T_9988d_row11_col17, #T_9988d_row11_col18, #T_9988d_row12_col14, #T_9988d_row13_col2, #T_9988d_row13_col5, #T_9988d_row17_col6 {
#   background-color: #fffebe;
#   color: #000000;
# }
# #T_9988d_row0_col2, #T_9988d_row2_col1, #T_9988d_row2_col14, #T_9988d_row2_col21, #T_9988d_row3_col1, #T_9988d_row3_col11, #T_9988d_row3_col20, #T_9988d_row4_col1, #T_9988d_row4_col5, #T_9988d_row4_col11, #T_9988d_row5_col19, #T_9988d_row6_col5, #T_9988d_row6_col20, #T_9988d_row6_col21, #T_9988d_row7_col1, #T_9988d_row7_col8, #T_9988d_row7_col16, #T_9988d_row7_col18, #T_9988d_row8_col16, #T_9988d_row10_col3, #T_9988d_row10_col20, #T_9988d_row11_col5, #T_9988d_row11_col11, #T_9988d_row12_col20, #T_9988d_row14_col3, #T_9988d_row14_col5, #T_9988d_row15_col5 {
#   background-color: #e6f598;
#   color: #000000;
# }
# #T_9988d_row0_col3, #T_9988d_row0_col5, #T_9988d_row1_col21, #T_9988d_row2_col20, #T_9988d_row3_col9, #T_9988d_row3_col19, #T_9988d_row4_col23, #T_9988d_row6_col1, #T_9988d_row7_col20, #T_9988d_row8_col23, #T_9988d_row9_col21, #T_9988d_row10_col18, #T_9988d_row11_col3, #T_9988d_row11_col7, #T_9988d_row11_col20, #T_9988d_row11_col21, #T_9988d_row12_col2, #T_9988d_row12_col5, #T_9988d_row13_col1, #T_9988d_row13_col3, #T_9988d_row13_col8, #T_9988d_row13_col22, #T_9988d_row15_col2, #T_9988d_row16_col15 {
#   background-color: #aadca4;
#   color: #000000;
# }
# #T_9988d_row0_col4, #T_9988d_row0_col7, #T_9988d_row0_col8, #T_9988d_row0_col10, #T_9988d_row0_col12, #T_9988d_row0_col15, #T_9988d_row0_col17, #T_9988d_row0_col18, #T_9988d_row0_col19, #T_9988d_row0_col20, #T_9988d_row0_col22, #T_9988d_row0_col23, #T_9988d_row1_col2, #T_9988d_row1_col4, #T_9988d_row1_col6, #T_9988d_row1_col8, #T_9988d_row1_col9, #T_9988d_row1_col10, #T_9988d_row1_col12, #T_9988d_row1_col13, #T_9988d_row1_col14, #T_9988d_row1_col15, #T_9988d_row1_col16, #T_9988d_row1_col17, #T_9988d_row1_col18, #T_9988d_row1_col19, #T_9988d_row1_col22, #T_9988d_row1_col23, #T_9988d_row2_col2, #T_9988d_row2_col4, #T_9988d_row2_col6, #T_9988d_row2_col7, #T_9988d_row2_col8, #T_9988d_row2_col9, #T_9988d_row2_col10, #T_9988d_row2_col12, #T_9988d_row2_col13, #T_9988d_row2_col17, #T_9988d_row2_col18, #T_9988d_row2_col19, #T_9988d_row2_col22, #T_9988d_row2_col23, #T_9988d_row3_col4, #T_9988d_row3_col6, #T_9988d_row3_col8, #T_9988d_row3_col10, #T_9988d_row3_col13, #T_9988d_row3_col14, #T_9988d_row3_col15, #T_9988d_row3_col17, #T_9988d_row4_col2, #T_9988d_row4_col9, #T_9988d_row4_col10, #T_9988d_row4_col12, #T_9988d_row4_col13, #T_9988d_row4_col17, #T_9988d_row4_col18, #T_9988d_row4_col19, #T_9988d_row4_col20, #T_9988d_row5_col4, #T_9988d_row5_col7, #T_9988d_row5_col8, #T_9988d_row5_col9, #T_9988d_row5_col10, #T_9988d_row5_col12, #T_9988d_row5_col13, #T_9988d_row5_col15, #T_9988d_row5_col17, #T_9988d_row5_col23, #T_9988d_row6_col2, #T_9988d_row6_col4, #T_9988d_row6_col6, #T_9988d_row6_col7, #T_9988d_row6_col10, #T_9988d_row6_col12, #T_9988d_row6_col13, #T_9988d_row6_col14, #T_9988d_row6_col15, #T_9988d_row6_col17, #T_9988d_row6_col18, #T_9988d_row6_col19, #T_9988d_row6_col23, #T_9988d_row7_col2, #T_9988d_row7_col4, #T_9988d_row7_col6, #T_9988d_row7_col10, #T_9988d_row7_col12, #T_9988d_row7_col13, #T_9988d_row7_col15, #T_9988d_row7_col19, #T_9988d_row7_col22, #T_9988d_row8_col2, #T_9988d_row8_col4, #T_9988d_row8_col6, #T_9988d_row8_col7, #T_9988d_row8_col8, #T_9988d_row8_col9, #T_9988d_row8_col10, #T_9988d_row8_col12, #T_9988d_row8_col14, #T_9988d_row8_col15, #T_9988d_row8_col19, #T_9988d_row8_col22, #T_9988d_row9_col2, #T_9988d_row9_col4, #T_9988d_row9_col6, #T_9988d_row9_col7, #T_9988d_row9_col8, #T_9988d_row9_col9, #T_9988d_row9_col10, #T_9988d_row9_col12, #T_9988d_row9_col13, #T_9988d_row9_col14, #T_9988d_row9_col15, #T_9988d_row9_col17, #T_9988d_row9_col19, #T_9988d_row9_col20, #T_9988d_row9_col23, #T_9988d_row10_col4, #T_9988d_row10_col6, #T_9988d_row10_col7, #T_9988d_row10_col8, #T_9988d_row10_col9, #T_9988d_row10_col10, #T_9988d_row10_col12, #T_9988d_row10_col13, #T_9988d_row10_col15, #T_9988d_row10_col19, #T_9988d_row10_col23, #T_9988d_row11_col4, #T_9988d_row11_col10, #T_9988d_row11_col12, #T_9988d_row11_col13, #T_9988d_row11_col19, #T_9988d_row11_col22, #T_9988d_row11_col23, #T_9988d_row12_col4, #T_9988d_row12_col8, #T_9988d_row12_col9, #T_9988d_row12_col10, #T_9988d_row12_col12, #T_9988d_row12_col13, #T_9988d_row12_col15, #T_9988d_row12_col19, #T_9988d_row12_col23, #T_9988d_row13_col4, #T_9988d_row13_col6, #T_9988d_row13_col7, #T_9988d_row13_col9, #T_9988d_row13_col10, #T_9988d_row13_col12, #T_9988d_row13_col13, #T_9988d_row13_col15, #T_9988d_row13_col17, #T_9988d_row13_col19, #T_9988d_row13_col23, #T_9988d_row14_col1, #T_9988d_row14_col4, #T_9988d_row14_col6, #T_9988d_row14_col7, #T_9988d_row14_col8, #T_9988d_row14_col9, #T_9988d_row14_col10, #T_9988d_row14_col11, #T_9988d_row14_col12, #T_9988d_row14_col13, #T_9988d_row14_col14, #T_9988d_row14_col15, #T_9988d_row14_col16, #T_9988d_row14_col17, #T_9988d_row14_col19, #T_9988d_row14_col20, #T_9988d_row14_col21, #T_9988d_row14_col22, #T_9988d_row14_col23, #T_9988d_row15_col1, #T_9988d_row15_col4, #T_9988d_row15_col6, #T_9988d_row15_col7, #T_9988d_row15_col8, #T_9988d_row15_col9, #T_9988d_row15_col11, #T_9988d_row15_col12, #T_9988d_row15_col13, #T_9988d_row15_col14, #T_9988d_row15_col15, #T_9988d_row15_col16, #T_9988d_row15_col17, #T_9988d_row15_col19, #T_9988d_row15_col20, #T_99 ...
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_9988d_row0_col6, #T_9988d_row0_col16, #T_9988d_row1_col1, #T_9988d_row1_col7, #T_9988d_row3_col7, #T_9988d_row3_col12, #T_9988d_row3_col16, #T_9988d_row3_col22, #T_9988d_row4_col4, #T_9988d_row4_col6, #T_9988d_row4_col7, #T_9988d_row4_col14, #T_9988d_row4_col22, #T_9988d_row5_col6, #T_9988d_row5_col16, #T_9988d_row5_col18, #T_9988d_row5_col22, #T_9988d_row6_col9, #T_9988d_row6_col11, #T_9988d_row6_col16, #T_9988d_row7_col7, #T_9988d_row7_col9, #T_9988d_row8_col20, #T_9988d_row9_col3, #T_9988d_row9_col18, #T_9988d_row9_col22, #T_9988d_row10_col22, #T_9988d_row11_col2, #T_9988d_row11_col6, #T_9988d_row11_col9, #T_9988d_row11_col14, #T_9988d_row12_col6, #T_9988d_row12_col7, #T_9988d_row13_col14, #T_9988d_row14_col2, #T_9988d_row17_col4, #T_9988d_row17_col12 {
#   background-color: #3387bc;
#   color: #f1f1f1;
# }
# #T_9988d_row0_col9, #T_9988d_row0_col13, #T_9988d_row1_col3, #T_9988d_row1_col11, #T_9988d_row1_col20, #T_9988d_row2_col16, #T_9988d_row3_col2, #T_9988d_row3_col3, #T_9988d_row3_col5, #T_9988d_row3_col23, #T_9988d_row4_col15, #T_9988d_row4_col16, #T_9988d_row5_col2, #T_9988d_row5_col3, #T_9988d_row6_col3, #T_9988d_row6_col8, #T_9988d_row6_col22, #T_9988d_row7_col23, #T_9988d_row8_col18, #T_9988d_row9_col16, #T_9988d_row10_col14, #T_9988d_row11_col8, #T_9988d_row11_col16, #T_9988d_row12_col18, #T_9988d_row13_col16, #T_9988d_row16_col3 {
#   background-color: #66c2a5;
#   color: #000000;
# }
# #T_9988d_row0_col14, #T_9988d_row5_col1, #T_9988d_row8_col1, #T_9988d_row11_col1, #T_9988d_row12_col1 {
#   background-color: #d43d4f;
#   color: #f1f1f1;
# }
# #T_9988d_row2_col11, #T_9988d_row2_col15, #T_9988d_row3_col21, #T_9988d_row4_col3, #T_9988d_row5_col5, #T_9988d_row5_col21, #T_9988d_row7_col3, #T_9988d_row7_col5, #T_9988d_row7_col14, #T_9988d_row10_col2, #T_9988d_row13_col21, #T_9988d_row15_col3 {
#   background-color: #fee08b;

# %%
# merge with other demographic details from subj_df in order to make a table for your paper:
subj_df.head(1)
# Out:
#    Site MSSMCode  OtherCodes  Day1  Day2  LongVersion      Date1 Experimenter  \
# 3  MSSM    MS012         NaN     1     0            1 2022-08-10      Lizbeth
#
#    Micros  Resp  ... Minerva   Age  BDI  BAI  IQ  Education  Handedness  Sex  \
# 3     0.0     0  ...       1  20.0  NaN  NaN NaN        NaN           R   F
#
#     Race     Ethnicity
# 3  White  Not Hispanic
#
# [1 rows x 25 columns]
