# %% [markdown]
# # Smoke Test: Load Sample Data
#
# Load bundled sample FIF data through the stable workflow helper.

# %%
from pathlib import Path
from LFPAnalysis import LoadConfig, load_lfp

raw = load_lfp(LoadConfig(path=Path('../../data/sample_ieeg.fif'), file_format='mne'))
print(raw)
print(raw.info['sfreq'], len(raw.ch_names))
