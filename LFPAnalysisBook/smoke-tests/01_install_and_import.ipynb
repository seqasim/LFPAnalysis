# %% [markdown]
# # Smoke Test: Install and Import
#
# This notebook verifies that the stable public API imports cleanly.

# %%
import LFPAnalysis
from LFPAnalysis import LoadConfig, PipelineConfig, run_pipeline

print('Public API import succeeded')
print(sorted(name for name in LFPAnalysis.__all__ if name.endswith('Config') or name == 'run_pipeline'))
